# %%
import requests
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import pandas as pd
import re

# %%
def get_html(url):
   _html = ""
   resp = requests.get(url)
   if resp.status_code == 200:
      _html = resp.text
   return _html

driver = webdriver.Chrome('/Users/abcd0/Downloads/chromedriver')

# %%
URL = "https://smartstore.naver.com/pet1/products/3748418081#revw"
html = get_html(URL)
soup = bs(html, 'html.parser')

# %%
# Set time wait
driver.implicitly_wait(3)

# %%
# Get the URL
driver.get(URL)

# %% [markdown]
# ## Define Get Functions

# %%
# Woolworth price crawling
def get_woolworth():
    html = driver.page_source
    soup = bs(html, 'html.parser')

    user_id = soup.select('div[class=area_status_user]')
    prices = soup.select('div[class=shelfProductTile-cupPrice]')

    title = []
    price = []

    for t in titles:
        title.append(t.text.strip())

    for p in prices:
        price.append(p.text.strip())
    
    return title, price

# %%
# Price - Name ValueError: arrays must all be same length
df_ww = pd.DataFrame({'Product':get_woolworth()[0], 'Price':get_woolworth()[1]})

# %% [markdown]
# ### Review Crawler

# %% [markdown]
# **Naver Review Crawler** starts here

# %%
html = driver.page_source
soup = bs(html, 'html.parser')
user_detail = soup.select('div[class=area_status_user]')
user_star = soup.select('span[class=number_grade]')
user_review = soup.select('p > span[class=text]')

user_details = []
user_stars = []
user_reviews = []

# for star in user_star:
#     print(star.text.strip())
for ud in user_detail:
    user_details.append(ud.text.strip('\n신고').splitlines())

for star in user_star:
    user_stars.append(star.text.strip())
    
for review in user_review:
    user_reviews.append(review.extract().prettify().strip('<span class="text">').strip('</').replace('\n ', '').replace('\n', ''))

# %%
# Seperate UID, PD, Option
user_id = []
purchase_date = []
option = []
for i in range(len(user_details)):
    user_id.append(user_details[i][0])
    purchase_date.append(user_details[i][1])
    option.append(user_details[i][2])

# %%
df = pd.DataFrame({'User_Stars' : user_stars[4:], 'User_ID' : user_id, 'Purchase_Date' : purchase_date,
                   'Option': option, 'User_Reviews' : user_reviews, })

# %%
df
# Out:
#    User_Stars   User_ID Purchase_Date                    Option  \
# 0           5  myj3****     19.02.13.  옵션 : 색상: 화이트 + 사은품(필터5개)
# 1           5  rudt****     19.01.20.  옵션 : 색상: 화이트 + 사은품(필터5개)
# 2           5  1987****     19.01.25.  옵션 : 색상: 화이트 + 사은품(필터5개)
# 3           5  yhun****     18.12.30.              옵션 : 색상: 화이트
# 4           2  park****     19.02.12.  옵션 : 색상: 화이트 + 사은품(필터5개)
# 5           3  shor****     18.12.28.              옵션 : 색상: 화이트
# 6           4  cndj****     19.01.23.               옵션 : 색상: 민트
# 7           5  ko84****     19.01.29.  옵션 : 색상: 화이트 + 사은품(필터5개)
# 8           5  iewo****     19.01.04.              옵션 : 색상: 화이트
# 9           5  skfr****     19.01.03.              옵션 : 색상: 화이트
# 10          5  babo****     18.12.12.       옵션 : 색상: 색상랜덤(임의)발송
# 11          4  dbrd****     18.12.07.               옵션 : 색상: 핑크
# 12          5  qksd****     19.01.08.              옵션 : 색상: 화이트
# 13          4  teso****     18.12.30.              옵션 : 색상: 화이트
# 14          5  hara****     18.12.27.              옵션 : 색상: 화이트
# 15          5  marv****     18.12.19.               옵션 : 색상: 핑크
# 16          4  dlsg****     18.12.15.               옵션 : 색상: 핑크
# 17          3  sen3****     19.01.03.              옵션 : 색상: 화이트
# 18          5  somi****     18.12.13.               옵션 : 색상: 핑크
# 19          5  tint****     18.11.27.              옵션 : 색상: 화이트
#
#                                          User_Reviews
# 0   작은데 분무량이 나름 좋아요 흰색에 귀여운 토끼 모양까지 맘에들어요계속 분사와 삼초...
# 1   넘나 넘나리 만족합니다!!! 필터까지 주셔서 오래오래 잘 쓸 것 같아요!소음 문제도...
# 2   방금 받았어요 회사 히터때문에 너무 건조해서 구매했는데 생각했던것보다는 작더라구요 ...
# 3   크기에 비해서 분무량 짱짱해요. 설명대로 8~9시간 사용가능하고 청소도 간편해요. ...
# 4   9시간이 아니라 6 시간정도 지나니까 금방 꺼지내요~ 또 분사력도 생각보다 약하구 ...
# 5   친구가 쓰는거 빌려썼다가 소음도 없이 분사력도 엄청 좋길래 구매했습니다.앞에 그림은...
# 6   잠깐 틀어봤는데 집에있는 다른 가습기보다 분무량이 훨씬 많아서 깜짝놀랐네요;;; 가...
# 7   사는 김에 필터 5개 더 받는 흰색으로 구매했어요. 깔끔하고 귀엽네요. 분사력도 괜...
# 8   사무실에서 씁니다. 이리저리 색깔있는것 보다 흰색이 깨끗하고 심플해서 좋네요. 설명...
# 9   아주 미니미니하지만 분사력은 정말 마음에 듭니다.약할줄 알았는데 정말 좋아요@ 무드...
# 10  분사력최고네요색상랜덤해서 2천원 싸게 샀는데 여기에 판매하는 색상은 파스텔톤색이라 ...
# 11  화요일쯤 받아서 사용중인데 쪼꼬만게 분사력도 쎄고 좋아요 ㅎㅎ 물을 max까지 받아...
# 12  너무 귀엽고, 성능도 괜찮네요. 미니여서 잘 안될줄 알았는데, 생각보다 분무량도 많...
# 13  배송 빨라서 좋습니다. 주문 다음날 바로 왔어요 실물 앙증맞고 귀엽네요ㅋㅋ 가습 잘...
# 14  배송도 바로 보내주시고 화이트라 할인된가격에필터까지 다섯개 추가로 더ㅈ받았으니 완전...
# 15  가습기 사면서 고려했던건 딱 두개에요 분사력과 세척이 쉬운지. 세척이 번거로우면 비...
# 16  배송 빠르고요오자마자 사용해봤어요일단 디자인은 진짜 이뻐요사이즈도  작아서 책상에 ...
# 17  가격대비 제품구성이나 가습기능, 전등기능 괜찮은 편입니다.다만, USB연결선이 불량...
# 18  비염이 심해서 구입했습니다. 생각보다 분무량 넉넉하구요, max로 채워서 꺼짐없이계...
# 19  주문하고 그 다음날 받았습니다 디자인은 화면 그대로 깔끔하고 귀엽습니다분무량 좋습니...

# %%
df.to_excel("review_crawling.xlsx")

# %% [markdown]
# ## Stock market data parser

# %%
from bs4 import BeautifulSoup
import requests

maximum = 0
page = 2

URL = 'https://finviz.com/screener.ashx?v=111&f=exch_nyse&r=21'
response = requests.get(URL)
source = response.text
soup = BeautifulSoup(source, 'html.parser')

# %%
while 1:
	page_list = soup.findAll("a", {"class": "screener-pages" + str(page)})
	if not page_list:
		maximum = page - 1
		break
	page = page + 20
print("Total " + str(maximum) + " Pages found.")
# Out:
# 총 1 개의 페이지가 확인 됬습니다.

# %%
# Get data from website, up to page 4201
results = []

for i in range (1,4221,20):
    whole_source = ""
    page_number = i
    URL = 'https://finviz.com/screener.ashx?v=111&f=exch_nyse&r=' + str(page_number)
    URL
    response = requests.get(URL)
    whole_source = whole_source + response.text
    soup = BeautifulSoup(whole_source, 'html.parser')
    table = soup.find_all(lambda tag: tag.name=='tr')
    rows = table[26].findAll(lambda tag: tag.name=='td')
    out = []
    x = []

    for i in range(len(rows)):
        td=rows[i].find_all('td')
        out=out+[x.text for x in td]

    x = out[290:-2]
    results.append(x)

#results
# Out:
# [['1',
#   'A',
#   'Agilent Technologies, Inc.',
#   'Healthcare',
#   'Medical Laboratories & Research',
#   'USA',
#   '25.89B',
#   '22.70',
#   '81.42',
#   '-0.33%',
#   '1,254,742',
#   '2',
#   'AA',
#   'Alcoa Corporation',
#   'Basic Materials',
#   'Aluminum',
#   'USA',
#   '5.41B',
#   '24.21',
#   '29.10',
#   '-1.89%',
#   '2,355,477',
#   '3',
#   'AAAU',
#   'Perth Mint Physical Gold ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '13.02',
#   '0.50%',
#   '25,889',
#   '4',
#   'AAC',
#   'AAC Holdings, Inc.',
#   'Healthcare',
#   'Specialized Health Services',
#   'USA',
#   '50.19M',
#   '-',
#   '2.10',
#   '1.94%',
#   '79,707',
#   '5',
#   'AADR',
#   'AdvisorShares Dorsey Wright ADR ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '46.24',
#   '-0.68%',
#   '5,995',
#   '6',
#   'AAMC',
#   'Altisource Asset Management Corporation',
#   'Financial',
#   'Asset Management',
#   'USA',
#   '47.08M',
#   '-',
#   '29.80',
#   '-0.67%',
#   '3,288',
#   '7',
#   'AAN',
#   "Aaron's, Inc.",
#   'Services',
#   'Rental & Leasing Services',
#   'USA',
#   '3.59B',
#   '19.06',
#   '52.88',
#   '-1.27%',
#   '265,594',
#   '8',
#   'AAP',
#   'Advance Auto Parts, Inc.',
#   'Services',
#   'Auto Parts Stores',
#   'USA',
#   '12.82B',
#   '31.06',
#   '175.65',
#   '-1.09%',
#   '616,239',
#   '9',
#   'AAT',
#   'American Assets Trust, Inc.',
#   'Financial',
#   'REIT - Retail',
#   'USA',
#   '2.14B',
#   '108.62',
#   '45.51',
#   '-1.07%',
#   '225,347',
#   '10',
#   'AAU',
#   'Almaden Minerals Ltd.',
#   'Basic Materials',
#   'Gold',
#   'Canada',
#   '62.37M',
#   '-',
#   '0.57',
#   '1.20%',
#   '37,823',
#   '11',
#   'AB',
#   'AllianceBernstein Holding L.P.',
#   'Financial',
#   'Asset Management',
#   'USA',
#   '2.79B',
#   '11.59',
#   '29.02',
#   '-1.02%',
#   '227,646',
#   '12',
#   'ABB',
#   'ABB Ltd',
#   'Industrial Goods',
#   'Diversified Machinery',
#   'Switzerland',
#   '42.46B',
#   '28.73',
#   '19.48',
#   '-1.37%',
#   '1,689,433',
#   '13',
#   'ABBV',
#   'AbbVie Inc.',
#   'Healthcare',
#   'Drug Manufacturers - Major',
#   'USA',
#   '122.46B',
#   '22.82',
#   '82.69',
#   '-1.54%',
#   '3,712,813',
#   '14',
#   'ABC',
#   'AmerisourceBergen Corporation',
#   'Services',
#   'Drugs Wholesale',
#   'USA',
#   '16.07B',
#   '14.99',
#   '77.43',
#   '-0.88%',
#   '957,123',
#   '15',
#   'ABEV',
#   'Ambev S.A.',
#   'Consumer Goods',
#   'Beverages - Brewers',
#   'Brazil',
#   '71.68B',
#   '25.91',
#   '4.56',
#   '1.56%',
#   '31,511,586',
#   '16',
#   'ABG',
#   'Asbury Automotive Group, Inc.',
#   'Services',
#   'Auto Dealerships',
#   'USA',
#   '1.42B',
#   '8.65',
#   '71.74',
#   '-0.58%',
#   '104,915',
#   '17',
#   'ABM',
#   'ABM Industries Incorporated',
#   'Services',
#   'Business Services',
#   'USA',
#   '2.40B',
#   '31.16',
#   '36.49',
#   '-1.54%',
#   '234,952',
#   '18',
#   'ABR',
#   'Arbor Realty Trust, Inc.',
#   'Financial',
#   'REIT - Diversified',
#   'USA',
#   '1.14B',
#   '9.13',
#   '13.49',
#   '-0.66%',
#   '900,900',
#   '19',
#   'ABT',
#   'Abbott Laboratories',
#   'Healthcare',
#   'Medical Appliances & Equipment',
#   'USA',
#   '137.52B',
#   '56.52',
#   '78.67',
#   '0.19%',
#   '4,836,715',
#   '20',
#   'AC',
#   'Associated Capital Group, Inc.',
#   'Financial',
#   'Asset Management',
#   'USA',
#   '890.48M',
#   '-',
#   '39.28',
#   '1.16%',
#   '3,151'],
#  ['21',
#   'ACB',
#   'Aurora Cannabis Inc.',
#   'Healthcare',
#   'Drug Manufacturers - Other',
#   'Canada',
#   '8.50B',
#   '40.79',
#   '8.81',
#   '-2.54%',
#   '21,751,244',
#   '22',
#   'ACC',
#   'American Campus Communities, Inc.',
#   'Financial',
#   'REIT - Residential',
#   'USA',
#   '6.50B',
#   '56.54',
#   '47.44',
#   '-0.88%',
#   '609,182',
#   '23',
#   'ACCO',
#   'ACCO Brands Corporation',
#   'Consumer Goods',
#   'Office Supplies',
#   'USA',
#   '865.88M',
#   '8.25',
#   '8.53',
#   '-2.18%',
#   '556,253',
#   '24',
#   'ACH',
#   'Aluminum Corporation of China Limited',
#   'Basic Materials',
#   'Aluminum',
#   'China',
#   '10.16B',
#   '84.02',
#   '10.67',
#   '-1.57%',
#   '75,469',
#   '25',
#   'ACIM',
#   'SPDR MSCI ACWI IMI ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '79.77',
#   '-0.31%',
#   '2,679',
#   '26',
#   'ACM',
#   'AECOM',
#   'Services',
#   'Technical Services',
#   'USA',
#   '4.77B',
#   '73.96',
#   '30.84',
#   '-1.91%',
#   '405,785',
#   '27',
#   'ACN',
#   'Accenture plc',
#   'Technology',
#   'Information Technology Services',
#   'Ireland',
#   '118.50B',
#   '25.63',
#   '177.73',
#   '-0.66%',
#   '1,813,989',
#   '28',
#   'ACP',
#   'Aberdeen Income Credit Strategies Fund',
#   'Financial',
#   'Closed-End Fund - Debt',
#   'USA',
#   '-',
#   '-',
#   '12.33',
#   '0.08%',
#   '58,251',
#   '29',
#   'ACRE',
#   'Ares Commercial Real Estate Corporation',
#   'Financial',
#   'REIT - Diversified',
#   'USA',
#   '440.86M',
#   '11.45',
#   '15.42',
#   '0.00%',
#   '171,270',
#   '30',
#   'ACSG',
#   'Xtrackers MSCI ACWI ex USA ESG Leaders Equity ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '26.54',
#   '-0.29%',
#   '100',
#   '31',
#   'ACU',
#   'Acme United Corporation',
#   'Consumer Goods',
#   'Housewares & Accessories',
#   'USA',
#   '63.63M',
#   '15.34',
#   '19.64',
#   '2.03%',
#   '23,055',
#   '32',
#   'ACV',
#   'AllianzGI Diversified Income & Convertible Fund',
#   'Consumer Goods',
#   'Personal Products',
#   'USA',
#   '-',
#   '-',
#   '22.92',
#   '-1.38%',
#   '40,620',
#   '33',
#   'ACWF',
#   'iShares Edge MSCI Multifactor Global ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '29.55',
#   '-0.74%',
#   '11,884',
#   '34',
#   'ACY',
#   'AeroCentury Corp.',
#   'Services',
#   'Rental & Leasing Services',
#   'USA',
#   '18.55M',
#   '-',
#   '11.74',
#   '1.02%',
#   '413',
#   '35',
#   'ADC',
#   'Agree Realty Corporation',
#   'Financial',
#   'Property Management',
#   'USA',
#   '2.52B',
#   '38.26',
#   '67.69',
#   '-0.35%',
#   '142,404',
#   '36',
#   'ADM',
#   'Archer-Daniels-Midland Company',
#   'Consumer Goods',
#   'Farm Products',
#   'USA',
#   '24.13B',
#   '13.65',
#   '42.78',
#   '-0.72%',
#   '4,127,563',
#   '37',
#   'ADNT',
#   'Adient plc',
#   'Consumer Goods',
#   'Auto Parts',
#   'Ireland',
#   '1.54B',
#   '-',
#   '16.47',
#   '-2.02%',
#   '1,408,540',
#   '38',
#   'ADS',
#   'Alliance Data Systems Corporation',
#   'Services',
#   'Business Services',
#   'USA',
#   '9.54B',
#   '10.44',
#   '177.21',
#   '-0.64%',
#   '406,143',
#   '39',
#   'ADSW',
#   'Advanced Disposal Services, Inc.',
#   'Industrial Goods',
#   'Waste Management',
#   'USA',
#   '2.45B',
#   '262.67',
#   '27.58',
#   '-0.68%',
#   '258,207',
#   '40',
#   'ADT',
#   'ADT Inc.',
#   'Services',
#   'Security & Protection Services',
#   'USA',
#   '4.95B',
#   '-',
#   '6.49',
#   '-1.82%',
#   '7,404,563'],
#  ['41',
#   'ADX',
#   'Adams Diversified Equity Fund, Inc.',
#   'Financial',
#   'Closed-End Fund - Equity',
#   'USA',
#   '1.56B',
#   '-',
#   '14.73',
#   '-0.61%',
#   '271,006',
#   '42',
#   'AE',
#   'Adams Resources & Energy, Inc.',
#   'Basic Materials',
#   'Oil & Gas Refining & Marketing',
#   'USA',
#   '156.14M',
#   '12.50',
#   '37.00',
#   '-1.65%',
#   '1,919',
#   '43',
#   'AEE',
#   'Ameren Corporation',
#   'Utilities',
#   'Electric Utilities',
#   'USA',
#   '17.60B',
#   '21.70',
#   '72.02',
#   '0.49%',
#   '828,201',
#   '44',
#   'AEF',
#   'Aberdeen Emerging Markets Equity Income Fund, Inc.',
#   'Financial',
#   'Asset Management',
#   'United Kingdom',
#   '447.77M',
#   '-',
#   '7.49',
#   '-0.66%',
#   '90,531',
#   '45',
#   'AEG',
#   'Aegon N.V.',
#   'Financial',
#   'Life Insurance',
#   'Netherlands',
#   '10.52B',
#   '14.31',
#   '4.95',
#   '-1.20%',
#   '1,186,005',
#   '46',
#   'AEL',
#   'American Equity Investment Life Holding Company',
#   'Financial',
#   'Life Insurance',
#   'USA',
#   '2.47B',
#   '5.50',
#   '27.54',
#   '-2.96%',
#   '290,342',
#   '47',
#   'AEM',
#   'Agnico Eagle Mines Limited',
#   'Basic Materials',
#   'Gold',
#   'Canada',
#   '10.33B',
#   '-',
#   '43.69',
#   '-0.16%',
#   '950,199',
#   '48',
#   'AEO',
#   'American Eagle Outfitters, Inc.',
#   'Services',
#   'Apparel Stores',
#   'USA',
#   '3.73B',
#   '14.73',
#   '21.67',
#   '-2.56%',
#   '3,487,144',
#   '49',
#   'AEP',
#   'American Electric Power Company, Inc.',
#   'Utilities',
#   'Electric Utilities',
#   'USA',
#   '40.76B',
#   '21.57',
#   '83.57',
#   '0.51%',
#   '1,898,481',
#   '50',
#   'AER',
#   'AerCap Holdings N.V.',
#   'Services',
#   'Air Services, Other',
#   'Netherlands',
#   '6.65B',
#   '6.90',
#   '47.10',
#   '-2.69%',
#   '1,182,738',
#   '51',
#   'AES',
#   'The AES Corporation',
#   'Utilities',
#   'Electric Utilities',
#   'USA',
#   '12.04B',
#   '11.75',
#   '18.11',
#   '0.67%',
#   '4,410,824',
#   '52',
#   'AFB',
#   'AllianceBernstein National Municipal Income Fund',
#   'Financial',
#   'Closed-End Fund - Debt',
#   'USA',
#   '371.96M',
#   '-',
#   '12.94',
#   '0.23%',
#   '72,284',
#   '53',
#   'AFG',
#   'American Financial Group, Inc.',
#   'Financial',
#   'Property & Casualty Insurance',
#   'USA',
#   '8.55B',
#   '16.41',
#   '95.88',
#   '-0.91%',
#   '337,666',
#   '54',
#   'AFGE',
#   'American Financial Group, Inc.',
#   'Financial',
#   'Property & Casualty Insurance',
#   'USA',
#   '-',
#   '-',
#   '25.58',
#   '-0.09%',
#   '9,726',
#   '55',
#   'AFI',
#   'Armstrong Flooring, Inc.',
#   'Industrial Goods',
#   'General Building Materials',
#   'USA',
#   '378.87M',
#   '-',
#   '14.59',
#   '0.41%',
#   '129,812',
#   '56',
#   'AFK',
#   'VanEck Vectors Africa Index ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '22.26',
#   '0.43%',
#   '8,539',
#   '57',
#   'AFL',
#   'Aflac Incorporated',
#   'Financial',
#   'Accident & Health Insurance',
#   'USA',
#   '36.56B',
#   '12.94',
#   '49.04',
#   '-0.16%',
#   '3,081,950',
#   '58',
#   'AFT',
#   'Apollo Senior Floating Rate Fund Inc.',
#   'Financial',
#   'Asset Management',
#   'USA',
#   '234.22M',
#   '-',
#   '15.04',
#   '-0.46%',
#   '66,666',
#   '59',
#   'AFTY',
#   'CSOP FTSE China A50 ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '17.66',
#   '-0.25%',
#   '3,526',
#   '60',
#   'AG',
#   'First Majestic Silver Corp.',
#   'Basic Materials',
#   'Silver',
#   'Canada',
#   '1.28B',
#   '-',
#   '6.60',
#   '0.92%',
#   '1,383,982'],
#  ['61',
#   'AGCO',
#   'AGCO Corporation',
#   'Industrial Goods',
#   'Farm & Construction Machinery',
#   'USA',
#   '5.34B',
#   '20.05',
#   '69.82',
#   '-2.28%',
#   '661,416',
#   '62',
#   'AGD',
#   'Aberdeen Global Dynamic Dividend Fund',
#   'Financial',
#   'Closed-End Fund - Foreign',
#   'USA',
#   '120.73M',
#   '62.06',
#   '9.62',
#   '-0.52%',
#   '38,114',
#   '63',
#   'AGE',
#   'AgeX Therapeutics, Inc.',
#   'Healthcare',
#   'Biotechnology',
#   'USA',
#   '153.68M',
#   '-',
#   '4.65',
#   '0.00%',
#   '85,996',
#   '64',
#   'AGG',
#   'iShares Core U.S. Aggregate Bond ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '108.40',
#   '0.06%',
#   '3,753,769',
#   '65',
#   'AGGE',
#   'IQ Enhanced Core Bond U.S. ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '18.77',
#   '0.08%',
#   '25',
#   '66',
#   'AGGP',
#   'IQ Enhanced Core Plus Bond U.S. ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '19.14',
#   '0.21%',
#   '3,649',
#   '67',
#   'AGGY',
#   'WisdomTree Yield Enhanced U.S. Aggregate Bond Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '49.75',
#   '0.12%',
#   '100,542',
#   '68',
#   'AGI',
#   'Alamos Gold Inc.',
#   'Basic Materials',
#   'Gold',
#   'Canada',
#   '2.02B',
#   '-',
#   '5.18',
#   '1.37%',
#   '1,356,952',
#   '69',
#   'AGM',
#   'Federal Agricultural Mortgage Corporation',
#   'Financial',
#   'Credit Services',
#   'USA',
#   '775.77M',
#   '8.43',
#   '74.45',
#   '-1.47%',
#   '42,058',
#   '70',
#   'AGM-A',
#   'Federal Agricultural Mortgage Corporation',
#   'Financial',
#   'Credit Services',
#   'USA',
#   '72.01M',
#   '7.91',
#   '69.86',
#   '-0.43%',
#   '2,122',
#   '71',
#   'AGN',
#   'Allergan plc',
#   'Healthcare',
#   'Drugs - Generic',
#   'USA',
#   '48.96B',
#   '-',
#   '147.44',
#   '-2.03%',
#   '1,224,270',
#   '72',
#   'AGO',
#   'Assured Guaranty Ltd.',
#   'Financial',
#   'Surety & Title Insurance',
#   'Bermuda',
#   '4.64B',
#   '9.82',
#   '45.13',
#   '-0.73%',
#   '443,378',
#   '73',
#   'AGQ',
#   'ProShares Ultra Silver',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '24.80',
#   '-0.44%',
#   '87,623',
#   '74',
#   'AGR',
#   'Avangrid, Inc.',
#   'Utilities',
#   'Gas Utilities',
#   'USA',
#   '15.49B',
#   '24.51',
#   '50.72',
#   '0.38%',
#   '279,043',
#   '75',
#   'AGRO',
#   'Adecoagro S.A.',
#   'Consumer Goods',
#   'Farm Products',
#   'Luxembourg',
#   '791.31M',
#   '-',
#   '7.09',
#   '-0.56%',
#   '358,528',
#   '76',
#   'AGS',
#   'PlayAGS, Inc.',
#   'Services',
#   'Gaming Activities',
#   'USA',
#   '862.08M',
#   '-',
#   '23.92',
#   '-2.65%',
#   '258,955',
#   '77',
#   'AGX',
#   'Argan, Inc.',
#   'Industrial Goods',
#   'Heavy Construction',
#   'USA',
#   '777.17M',
#   '13.05',
#   '50.27',
#   '-1.68%',
#   '150,487',
#   '78',
#   'AGZ',
#   'iShares Agency Bond ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '113.06',
#   '0.14%',
#   '43,365',
#   '79',
#   'AHC',
#   'A.H. Belo Corporation',
#   'Services',
#   'Publishing - Newspapers',
#   'USA',
#   '81.01M',
#   '-',
#   '3.94',
#   '3.14%',
#   '7,682',
#   '80',
#   'AHH',
#   'Armada Hoffler Properties, Inc.',
#   'Financial',
#   'REIT - Diversified',
#   'USA',
#   '1.05B',
#   '48.20',
#   '15.52',
#   '-0.70%',
#   '121,649'],
#  ['81',
#   'AHT',
#   'Ashford Hospitality Trust, Inc.',
#   'Financial',
#   'REIT - Hotel/Motel',
#   'USA',
#   '518.91M',
#   '-',
#   '5.17',
#   '-5.48%',
#   '639,360',
#   '82',
#   'AI',
#   'Arlington Asset Investment Corp.',
#   'Financial',
#   'Mortgage Investment',
#   'USA',
#   '286.43M',
#   '-',
#   '7.93',
#   '-0.50%',
#   '263,995',
#   '83',
#   'AIEQ',
#   'AI Powered Equity ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '26.35',
#   '-0.38%',
#   '68,111',
#   '84',
#   'AIF',
#   'Apollo Tactical Income Fund Inc.',
#   'Financial',
#   'Asset Management',
#   'USA',
#   '214.65M',
#   '-',
#   '14.84',
#   '-0.40%',
#   '64,152',
#   '85',
#   'AIG',
#   'American International Group, Inc.',
#   'Financial',
#   'Property & Casualty Insurance',
#   'USA',
#   '39.60B',
#   '-',
#   '44.63',
#   '-0.53%',
#   '3,396,986',
#   '86',
#   'AIIQ',
#   'Equbot AI Powered International Equity ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '24.30',
#   '-0.47%',
#   '54',
#   '87',
#   'AIN',
#   'Albany International Corp.',
#   'Industrial Goods',
#   'Textile Industrial',
#   'USA',
#   '2.31B',
#   '27.65',
#   '71.47',
#   '-0.87%',
#   '108,004',
#   '88',
#   'AINC',
#   'Ashford Inc.',
#   'Financial',
#   'Asset Management',
#   'USA',
#   '137.86M',
#   '34.98',
#   '56.50',
#   '0.00%',
#   '6,407',
#   '89',
#   'AIR',
#   'AAR Corp.',
#   'Industrial Goods',
#   'Aerospace/Defense Products & Services',
#   'USA',
#   '1.15B',
#   '17.43',
#   '33.14',
#   '-2.33%',
#   '186,758',
#   '90',
#   'AIRI',
#   'Air Industries Group',
#   'Industrial Goods',
#   'Aerospace/Defense Products & Services',
#   'USA',
#   '32.10M',
#   '-',
#   '1.14',
#   '5.56%',
#   '47,926',
#   '91',
#   'AIT',
#   'Applied Industrial Technologies, Inc.',
#   'Services',
#   'Industrial Equipment Wholesale',
#   'USA',
#   '2.26B',
#   '16.29',
#   '59.21',
#   '-2.04%',
#   '139,351',
#   '92',
#   'AIV',
#   'Apartment Investment and Management Company',
#   'Financial',
#   'REIT - Residential',
#   'USA',
#   '7.47B',
#   '11.63',
#   '50.47',
#   '-0.36%',
#   '827,607',
#   '93',
#   'AIZ',
#   'Assurant, Inc.',
#   'Financial',
#   'Accident & Health Insurance',
#   'USA',
#   '5.82B',
#   '22.77',
#   '94.31',
#   '-1.17%',
#   '506,964',
#   '94',
#   'AIZP',
#   'Assurant, Inc.',
#   'Financial',
#   'Insurance Brokers',
#   'USA',
#   '6.44B',
#   '26.08',
#   '103.80',
#   '-0.54%',
#   '318',
#   '95',
#   'AJG',
#   'Arthur J. Gallagher & Co.',
#   'Financial',
#   'Insurance Brokers',
#   'USA',
#   '14.51B',
#   '22.57',
#   '77.98',
#   '0.03%',
#   '1,812,462',
#   '96',
#   'AJRD',
#   'Aerojet Rocketdyne Holdings, Inc.',
#   'Industrial Goods',
#   'Aerospace/Defense - Major Diversified',
#   'USA',
#   '2.62B',
#   '19.19',
#   '33.54',
#   '-1.44%',
#   '5,068,044',
#   '97',
#   'AJX',
#   'Great Ajax Corp.',
#   'Financial',
#   'REIT - Diversified',
#   'USA',
#   '258.17M',
#   '12.58',
#   '13.66',
#   '-0.80%',
#   '33,030',
#   '98',
#   'AJXA',
#   'Great Ajax Corp. 7.25 CV SR NT 24',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '25.18',
#   '-0.40%',
#   '304',
#   '99',
#   'AKG',
#   'Asanko Gold Inc.',
#   'Basic Materials',
#   'Gold',
#   'Canada',
#   '151.47M',
#   '-',
#   '0.66',
#   '1.95%',
#   '136,125',
#   '100',
#   'AKO-A',
#   'Embotelladora Andina S.A.',
#   'Consumer Goods',
#   'Beverages - Soft Drinks',
#   'Chile',
#   '18.69B',
#   '20.70',
#   '19.75',
#   '-0.45%',
#   '172'],
#  ['101',
#   'AKO-B',
#   'Embotelladora Andina S.A.',
#   'Consumer Goods',
#   'Beverages - Soft Drinks',
#   'Chile',
#   '3.21B',
#   '24.10',
#   '22.20',
#   '-0.84%',
#   '12,909',
#   '102',
#   'AKP',
#   'Alliance California Municipal Income Fund, Inc.',
#   'Financial',
#   'Closed-End Fund - Debt',
#   'USA',
#   '125.75M',
#   '-',
#   '14.70',
#   '0.07%',
#   '16,173',
#   '103',
#   'AKR',
#   'Acadia Realty Trust',
#   'Financial',
#   'Property Management',
#   'USA',
#   '2.22B',
#   '86.09',
#   '27.29',
#   '-0.58%',
#   '538,288',
#   '104',
#   'AKS',
#   'AK Steel Holding Corporation',
#   'Basic Materials',
#   'Steel & Iron',
#   'USA',
#   '858.14M',
#   '4.79',
#   '2.76',
#   '-5.80%',
#   '6,499,782',
#   '105',
#   'AL',
#   'Air Lease Corporation',
#   'Services',
#   'Rental & Leasing Services',
#   'USA',
#   '3.93B',
#   '7.74',
#   '35.60',
#   '-2.73%',
#   '733,838',
#   '106',
#   'ALB',
#   'Albemarle Corporation',
#   'Basic Materials',
#   'Specialty Chemicals',
#   'USA',
#   '8.99B',
#   '13.92',
#   '84.78',
#   '-2.48%',
#   '1,483,972',
#   '107',
#   'ALE',
#   'ALLETE, Inc.',
#   'Utilities',
#   'Diversified Utilities',
#   'USA',
#   '4.21B',
#   '24.29',
#   '82.14',
#   '-0.30%',
#   '129,245',
#   '108',
#   'ALEX',
#   'Alexander & Baldwin, Inc.',
#   'Financial',
#   'Real Estate Development',
#   'USA',
#   '1.74B',
#   '-',
#   '24.02',
#   '-1.44%',
#   '175,172',
#   '109',
#   'ALG',
#   'Alamo Group Inc.',
#   'Industrial Goods',
#   'Farm & Construction Machinery',
#   'USA',
#   '1.16B',
#   '16.40',
#   '97.80',
#   '-3.49%',
#   '92,926',
#   '110',
#   'ALK',
#   'Alaska Air Group, Inc.',
#   'Services',
#   'Regional Airlines',
#   'USA',
#   '7.13B',
#   '16.41',
#   '57.84',
#   '-0.84%',
#   '1,026,724',
#   '111',
#   'ALL',
#   'The Allstate Corporation',
#   'Financial',
#   'Property & Casualty Insurance',
#   'USA',
#   '31.25B',
#   '16.27',
#   '94.36',
#   '-0.54%',
#   '1,079,537',
#   '112',
#   'ALLE',
#   'Allegion plc',
#   'Services',
#   'Security & Protection Services',
#   'Ireland',
#   '8.85B',
#   '21.65',
#   '93.49',
#   '-0.96%',
#   '724,686',
#   '113',
#   'ALLY',
#   'Ally Financial Inc.',
#   'Financial',
#   'Mortgage Investment',
#   'USA',
#   '11.49B',
#   '9.88',
#   '28.71',
#   '-0.93%',
#   '2,024,403',
#   '114',
#   'ALO',
#   'Alio Gold Inc.',
#   'Basic Materials',
#   'Gold',
#   'Canada',
#   '66.87M',
#   '-',
#   '0.79',
#   '-0.34%',
#   '71,006',
#   '115',
#   'ALSN',
#   'Allison Transmission Holdings, Inc.',
#   'Consumer Goods',
#   'Auto Parts',
#   'USA',
#   '5.81B',
#   '13.02',
#   '46.74',
#   '-0.49%',
#   '1,213,718',
#   '116',
#   'ALV',
#   'Autoliv, Inc.',
#   'Consumer Goods',
#   'Auto Parts',
#   'Sweden',
#   '6.95B',
#   '18.32',
#   '78.71',
#   '-1.30%',
#   '446,201',
#   '117',
#   'ALX',
#   "Alexander's, Inc.",
#   'Financial',
#   'REIT - Retail',
#   'USA',
#   '1.94B',
#   '34.89',
#   '386.18',
#   '-0.60%',
#   '12,148',
#   '118',
#   'AM',
#   'Antero Midstream Corporation',
#   'Basic Materials',
#   'Oil & Gas Pipelines',
#   'USA',
#   '6.93B',
#   '42.21',
#   '13.93',
#   '-2.25%',
#   '1,005,411',
#   '119',
#   'AMBO',
#   'Ambow Education Holding Ltd.',
#   'Services',
#   'Education & Training Services',
#   'China',
#   '133.86M',
#   '22.06',
#   '6.00',
#   '-0.33%',
#   '1,723',
#   '120',
#   'AMBR',
#   'Amber Road, Inc.',
#   'Technology',
#   'Application Software',
#   'USA',
#   '250.70M',
#   '-',
#   '8.89',
#   '2.18%',
#   '227,262'],
#  ['121',
#   'AMC',
#   'AMC Entertainment Holdings, Inc.',
#   'Services',
#   'Movie Production, Theaters',
#   'USA',
#   '1.68B',
#   '22.94',
#   '16.15',
#   '-0.98%',
#   '1,157,853',
#   '122',
#   'AME',
#   'AMETEK, Inc.',
#   'Industrial Goods',
#   'Diversified Machinery',
#   'USA',
#   '18.95B',
#   '25.38',
#   '83.55',
#   '-1.26%',
#   '642,030',
#   '123',
#   'AMG',
#   'Affiliated Managers Group, Inc.',
#   'Financial',
#   'Asset Management',
#   'USA',
#   '5.59B',
#   '25.66',
#   '109.96',
#   '-3.63%',
#   '659,375',
#   '124',
#   'AMH',
#   'American Homes 4 Rent',
#   'Financial',
#   'REIT - Residential',
#   'USA',
#   '6.74B',
#   '288.61',
#   '22.80',
#   '-0.61%',
#   '1,962,814',
#   '125',
#   'AMID',
#   'American Midstream Partners, LP',
#   'Basic Materials',
#   'Oil & Gas Pipelines',
#   'USA',
#   '281.33M',
#   '-',
#   '5.18',
#   '0.19%',
#   '183,538',
#   '126',
#   'AMJ',
#   'JPMorgan Alerian MLP Index ETN',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '25.46',
#   '-1.09%',
#   '1,161,884',
#   '127',
#   'AMJL',
#   'Credit Suisse X-Links Monthly Pay 2xLeveraged Alerian MLP Index ETN',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '14.77',
#   '-2.48%',
#   '16,025',
#   '128',
#   'AMLP',
#   'Alerian MLP ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '10.06',
#   '-0.69%',
#   '14,464,693',
#   '129',
#   'AMN',
#   'AMN Healthcare Services, Inc.',
#   'Industrial Goods',
#   'General Building Materials',
#   'USA',
#   '2.28B',
#   '16.88',
#   '49.13',
#   '-0.16%',
#   '273,418',
#   '130',
#   'AMP',
#   'Ameriprise Financial, Inc.',
#   'Financial',
#   'Asset Management',
#   'USA',
#   '18.39B',
#   '9.62',
#   '136.47',
#   '-1.49%',
#   '584,467',
#   '131',
#   'AMPE',
#   'Ampio Pharmaceuticals, Inc.',
#   'Healthcare',
#   'Biotechnology',
#   'USA',
#   '58.90M',
#   '1.27',
#   '0.51',
#   '-0.93%',
#   '289,669',
#   '132',
#   'AMRC',
#   'Ameresco, Inc.',
#   'Services',
#   'Technical Services',
#   'USA',
#   '746.87M',
#   '20.12',
#   '16.30',
#   '-0.79%',
#   '54,617',
#   '133',
#   'AMRX',
#   'Amneal Pharmaceuticals, Inc.',
#   'Healthcare',
#   'Drugs - Generic',
#   'USA',
#   '4.15B',
#   '-',
#   '13.72',
#   '-2.00%',
#   '511,134',
#   '134',
#   'AMS',
#   'American Shared Hospital Services',
#   'Healthcare',
#   'Specialized Health Services',
#   'USA',
#   '14.75M',
#   '14.01',
#   '2.58',
#   '-3.06%',
#   '19,082',
#   '135',
#   'AMT',
#   'American Tower Corporation (REIT)',
#   'Financial',
#   'REIT - Diversified',
#   'USA',
#   '86.72B',
#   '71.02',
#   '196.72',
#   '0.25%',
#   '1,708,208',
#   '136',
#   'AMU',
#   'UBS ETRACS Alerian MLP Index ETN',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '16.01',
#   '-1.23%',
#   '141,763',
#   '137',
#   'AMX',
#   'America Movil, S.A.B. de C.V.',
#   'Technology',
#   'Wireless Communications',
#   'Mexico',
#   '49.89B',
#   '20.55',
#   '15.76',
#   '0.51%',
#   '1,758,217',
#   '138',
#   'AMZA',
#   'InfraCap MLP ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '5.99',
#   '-1.48%',
#   '1,215,618',
#   '139',
#   'AN',
#   'AutoNation, Inc.',
#   'Services',
#   'Auto Dealerships',
#   'USA',
#   '3.33B',
#   '8.44',
#   '36.15',
#   '-0.96%',
#   '521,472',
#   '140',
#   'ANDX',
#   'Andeavor Logistics LP',
#   'Basic Materials',
#   'Oil & Gas Equipment & Services',
#   'USA',
#   '8.52B',
#   '14.02',
#   '34.85',
#   '-0.40%',
#   '591,978'],
#  ['141',
#   'ANET',
#   'Arista Networks, Inc.',
#   'Technology',
#   'Diversified Computer Systems',
#   'USA',
#   '24.18B',
#   '77.04',
#   '317.19',
#   '0.09%',
#   '442,646',
#   '142',
#   'ANF',
#   'Abercrombie & Fitch Co.',
#   'Services',
#   'Apparel Stores',
#   'USA',
#   '1.70B',
#   '26.01',
#   '24.74',
#   '-1.39%',
#   '1,583,089',
#   '143',
#   'ANFI',
#   'Amira Nature Foods Ltd.',
#   'Consumer Goods',
#   'Food - Major Diversified',
#   'United Arab Emirates',
#   '71.01M',
#   '-',
#   '1.54',
#   '-7.23%',
#   '511,091',
#   '144',
#   'ANGL',
#   'VanEck Vectors Fallen Angel High Yield Bond ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '28.83',
#   '0.00%',
#   '264,893',
#   '145',
#   'ANH',
#   'Anworth Mortgage Asset Corporation',
#   'Financial',
#   'REIT - Diversified',
#   'USA',
#   '404.11M',
#   '-',
#   '4.07',
#   '-0.49%',
#   '341,904',
#   '146',
#   'ANTM',
#   'Anthem, Inc.',
#   'Healthcare',
#   'Health Care Plans',
#   'USA',
#   '74.96B',
#   '20.58',
#   '290.10',
#   '0.21%',
#   '1,095,329',
#   '147',
#   'AOA',
#   'iShares Core Aggressive Allocation ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '54.10',
#   '-0.44%',
#   '61,732',
#   '148',
#   'AOD',
#   'Aberdeen Total Dynamic Dividend Fund',
#   'Financial',
#   'Closed-End Fund - Foreign',
#   'USA',
#   '899.62M',
#   '125.97',
#   '8.44',
#   '-0.24%',
#   '163,889',
#   '149',
#   'AOK',
#   'iShares Core Conservative Allocation ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '34.59',
#   '0.03%',
#   '30,669',
#   '150',
#   'AOM',
#   'iShares Core Moderate Allocation ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '38.07',
#   '-0.24%',
#   '118,495',
#   '151',
#   'AON',
#   'Aon plc',
#   'Financial',
#   'Insurance Brokers',
#   'United Kingdom',
#   '41.27B',
#   '37.12',
#   '172.00',
#   '-0.46%',
#   '730,990',
#   '152',
#   'AOR',
#   'iShares Core Growth Allocation ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '44.98',
#   '-0.27%',
#   '102,109',
#   '153',
#   'AOS',
#   'A. O. Smith Corporation',
#   'Industrial Goods',
#   'Industrial Electrical Equipment',
#   'USA',
#   '8.98B',
#   '20.86',
#   '53.84',
#   '-2.50%',
#   '1,021,129',
#   '154',
#   'AP',
#   'Ampco-Pittsburgh Corporation',
#   'Industrial Goods',
#   'Diversified Machinery',
#   'USA',
#   '39.64M',
#   '-',
#   '3.22',
#   '-1.53%',
#   '5,286',
#   '155',
#   'APA',
#   'Apache Corporation',
#   'Basic Materials',
#   'Independent Oil & Gas',
#   'USA',
#   '13.22B',
#   '44.38',
#   '34.88',
#   '-1.91%',
#   '2,700,357',
#   '156',
#   'APAM',
#   'Artisan Partners Asset Management Inc.',
#   'Financial',
#   'Asset Management',
#   'USA',
#   '2.00B',
#   '9.49',
#   '26.75',
#   '-0.56%',
#   '430,475',
#   '157',
#   'APC',
#   'Anadarko Petroleum Corporation',
#   'Basic Materials',
#   'Independent Oil & Gas',
#   'USA',
#   '22.21B',
#   '33.10',
#   '46.17',
#   '-2.16%',
#   '4,364,503',
#   '158',
#   'APD',
#   'Air Products and Chemicals, Inc.',
#   'Basic Materials',
#   'Chemicals - Major Diversified',
#   'USA',
#   '42.28B',
#   '25.56',
#   '192.28',
#   '-0.39%',
#   '600,109',
#   '159',
#   'APF',
#   'Morgan Stanley Asia-Pacific Fund, Inc.',
#   'Financial',
#   'Closed-End Fund - Foreign',
#   'USA',
#   '220.32M',
#   '-',
#   '16.78',
#   '0.12%',
#   '89,639',
#   '160',
#   'APH',
#   'Amphenol Corporation',
#   'Technology',
#   'Diversified Electronics',
#   'USA',
#   '30.40B',
#   '24.52',
#   '101.43',
#   '-1.32%',
#   '798,526'],
#  ['161',
#   'APHA',
#   'Aphria Inc.',
#   'Healthcare',
#   'Drug Manufacturers - Other',
#   'Canada',
#   '2.42B',
#   '32.34',
#   '9.67',
#   '-3.30%',
#   '2,973,306',
#   '162',
#   'APHB',
#   'AmpliPhi Biosciences Corporation',
#   'Healthcare',
#   'Biotechnology',
#   'USA',
#   '9.81M',
#   '-',
#   '0.29',
#   '0.76%',
#   '264,614',
#   '163',
#   'APLE',
#   'Apple Hospitality REIT, Inc.',
#   'Financial',
#   'REIT - Hotel/Motel',
#   'USA',
#   '3.65B',
#   '18.28',
#   '16.38',
#   '-2.03%',
#   '1,465,576',
#   '164',
#   'APO',
#   'Apollo Global Management, LLC',
#   'Financial',
#   'Diversified Investments',
#   'USA',
#   '5.65B',
#   '-',
#   '28.12',
#   '-1.40%',
#   '570,321',
#   '165',
#   'APRN',
#   'Blue Apron Holdings, Inc.',
#   'Services',
#   'Specialty Retail, Other',
#   'USA',
#   '211.25M',
#   '-',
#   '1.15',
#   '0.88%',
#   '4,688,549',
#   '166',
#   'APT',
#   'Alpha Pro Tech, Ltd.',
#   'Industrial Goods',
#   'General Building Materials',
#   'Canada',
#   '48.28M',
#   '13.55',
#   '3.55',
#   '-1.39%',
#   '11,427',
#   '167',
#   'APTS',
#   'Preferred Apartment Communities, Inc.',
#   'Financial',
#   'REIT - Residential',
#   'USA',
#   '618.49M',
#   '-',
#   '14.80',
#   '-2.37%',
#   '205,094',
#   '168',
#   'APTV',
#   'Aptiv PLC',
#   'Consumer Goods',
#   'Auto Parts',
#   'Ireland',
#   '22.98B',
#   '21.16',
#   '87.51',
#   '-1.11%',
#   '1,503,328',
#   '169',
#   'APU',
#   'AmeriGas Partners, L.P.',
#   'Utilities',
#   'Gas Utilities',
#   'USA',
#   '3.26B',
#   '39.23',
#   '35.35',
#   '0.23%',
#   '790,260',
#   '170',
#   'APY',
#   'Apergy Corporation',
#   'Basic Materials',
#   'Oil & Gas Equipment & Services',
#   'USA',
#   '3.13B',
#   '33.40',
#   '40.48',
#   '-0.39%',
#   '419,912',
#   '171',
#   'AQ',
#   'Aquantia Corp.',
#   'Services',
#   'Business Services',
#   'USA',
#   '322.78M',
#   '-',
#   '9.10',
#   '-0.33%',
#   '556,680',
#   '172',
#   'AQN',
#   'Algonquin Power & Utilities Corp.',
#   'Utilities',
#   'Diversified Utilities',
#   'Canada',
#   '5.42B',
#   '75.20',
#   '11.43',
#   '0.26%',
#   '352,076',
#   '173',
#   'AQUA',
#   'Evoqua Water Technologies Corp.',
#   'Industrial Goods',
#   'Pollution & Treatment Controls',
#   'USA',
#   '1.43B',
#   '-',
#   '12.77',
#   '-5.62%',
#   '618,706',
#   '174',
#   'AR',
#   'Antero Resources Corporation',
#   'Basic Materials',
#   'Oil & Gas Drilling & Exploration',
#   'USA',
#   '2.47B',
#   '-',
#   '8.55',
#   '-4.68%',
#   '5,429,321',
#   '175',
#   'ARA',
#   'American Renal Associates Holdings, Inc.',
#   'Healthcare',
#   'Medical Laboratories & Research',
#   'USA',
#   '193.82M',
#   '-',
#   '5.96',
#   '-0.67%',
#   '260,470',
#   '176',
#   'ARC',
#   'ARC Document Solutions, Inc.',
#   'Services',
#   'Business Services',
#   'USA',
#   '106.74M',
#   '11.83',
#   '2.33',
#   '2.19%',
#   '388,052',
#   '177',
#   'ARCH',
#   'Arch Coal, Inc.',
#   'Basic Materials',
#   'Industrial Metals & Minerals',
#   'USA',
#   '1.63B',
#   '5.78',
#   '88.65',
#   '-1.99%',
#   '147,373',
#   '178',
#   'ARCO',
#   'Arcos Dorados Holdings Inc.',
#   'Services',
#   'Restaurants',
#   'Argentina',
#   '1.47B',
#   '40.57',
#   '7.10',
#   '-0.28%',
#   '341,676',
#   '179',
#   'ARD',
#   'Ardagh Group S.A.',
#   'Consumer Goods',
#   'Packaging & Containers',
#   'Luxembourg',
#   '3.26B',
#   '-',
#   '13.75',
#   '-0.58%',
#   '25,916',
#   '180',
#   'ARDC',
#   'Ares Dynamic Credit Allocation Fund, Inc.',
#   'Financial',
#   'Asset Management',
#   'USA',
#   '-',
#   '-',
#   '15.02',
#   '-0.53%',
#   '67,239'],
#  ['181',
#   'ARE',
#   'Alexandria Real Estate Equities, Inc.',
#   'Financial',
#   'REIT - Office',
#   'USA',
#   '16.04B',
#   '41.11',
#   '143.12',
#   '-0.36%',
#   '347,384',
#   '182',
#   'ARES',
#   'Ares Management Corporation',
#   'Financial',
#   'Asset Management',
#   'USA',
#   '5.28B',
#   '81.73',
#   '23.62',
#   '-0.76%',
#   '503,621',
#   '183',
#   'ARGO',
#   'Argo Group International Holdings, Ltd.',
#   'Financial',
#   'Property & Casualty Insurance',
#   'Bermuda',
#   '2.36B',
#   '40.07',
#   '70.48',
#   '0.53%',
#   '135,484',
#   '184',
#   'ARGT',
#   'Global X MSCI Argentina ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '27.47',
#   '-1.22%',
#   '46,420',
#   '185',
#   'ARI',
#   'Apollo Commercial Real Estate Finance, Inc.',
#   'Financial',
#   'REIT - Diversified',
#   'USA',
#   '2.45B',
#   '12.51',
#   '18.31',
#   '-0.81%',
#   '989,722',
#   '186',
#   'ARI-PC',
#   'Apollo Commercial Real Estate Finance, Inc.',
#   'Financial',
#   'REIT - Diversified',
#   'USA',
#   '-',
#   '-',
#   '-',
#   '-',
#   '0',
#   '187',
#   'ARKF',
#   'ARK Fintech Innovation ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '22.12',
#   '-0.50%',
#   '17,349',
#   '188',
#   'ARKG',
#   'ARK Genomic Revolution Multi-Sector ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '33.83',
#   '-1.63%',
#   '182,331',
#   '189',
#   'ARKK',
#   'ARK Innovation ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '48.30',
#   '-1.04%',
#   '314,709',
#   '190',
#   'ARKQ',
#   'ARK Industrial Innovation ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '35.21',
#   '-1.21%',
#   '18,819',
#   '191',
#   'ARKW',
#   'ARK Web x.0 ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '53.18',
#   '-0.77%',
#   '52,062',
#   '192',
#   'ARL',
#   'American Realty Investors, Inc.',
#   'Financial',
#   'Property Management',
#   'USA',
#   '192.60M',
#   '1.12',
#   '12.06',
#   '-0.41%',
#   '446',
#   '193',
#   'ARLO',
#   'Arlo Technologies, Inc.',
#   'Technology',
#   'Security Software & Services',
#   'USA',
#   '294.41M',
#   '-',
#   '4.08',
#   '-1.92%',
#   '689,730',
#   '194',
#   'ARMK',
#   'Aramark',
#   'Services',
#   'Specialty Eateries',
#   'USA',
#   '7.42B',
#   '15.75',
#   '30.05',
#   '-3.22%',
#   '3,028,774',
#   '195',
#   'ARNC',
#   'Arconic Inc.',
#   'Basic Materials',
#   'Aluminum',
#   'USA',
#   '8.95B',
#   '14.40',
#   '20.00',
#   '-1.28%',
#   '4,124,896',
#   '196',
#   'AROC',
#   'Archrock, Inc.',
#   'Basic Materials',
#   'Oil & Gas Equipment & Services',
#   'USA',
#   '1.30B',
#   '75.60',
#   '10.13',
#   '-1.94%',
#   '499,962',
#   '197',
#   'ARR',
#   'ARMOUR Residential REIT, Inc.',
#   'Financial',
#   'REIT - Residential',
#   'USA',
#   '1.18B',
#   '-',
#   '19.85',
#   '-0.15%',
#   '620,994',
#   '198',
#   'ARW',
#   'Arrow Electronics, Inc.',
#   'Services',
#   'Electronics Wholesale',
#   'USA',
#   '7.09B',
#   '10.52',
#   '81.92',
#   '-1.37%',
#   '326,762',
#   '199',
#   'ASA',
#   'ASA Gold and Precious Metals Limited',
#   'Financial',
#   'Asset Management',
#   'USA',
#   '200.04M',
#   '-',
#   '10.37',
#   '0.48%',
#   '33,018',
#   '200',
#   'ASB',
#   'Associated Banc-Corp',
#   'Financial',
#   'Regional - Midwest Banks',
#   'USA',
#   '3.61B',
#   '12.19',
#   '21.96',
#   '-1.66%',
#   '704,932'],
#  ['201',
#   'ASC',
#   'Ardmore Shipping Corporation',
#   'Services',
#   'Shipping',
#   'Bermuda',
#   '199.56M',
#   '-',
#   '6.02',
#   '-0.82%',
#   '225,852',
#   '202',
#   'ASEA',
#   'Global X FTSE Southeast Asia ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '16.26',
#   '0.19%',
#   '57,856',
#   '203',
#   'ASG',
#   'Liberty All-Star Growth Fund, Inc.',
#   'Financial',
#   'Closed-End Fund - Equity',
#   'USA',
#   '155.48M',
#   '-',
#   '5.63',
#   '-1.05%',
#   '139,180',
#   '204',
#   'ASGN',
#   'ASGN Incorporated',
#   'Services',
#   'Staffing & Outsourcing Services',
#   'USA',
#   '3.39B',
#   '22.37',
#   '65.35',
#   '-2.39%',
#   '186,825',
#   '205',
#   'ASH',
#   'Ashland Global Holdings Inc.',
#   'Basic Materials',
#   'Chemicals - Major Diversified',
#   'USA',
#   '4.92B',
#   '98.28',
#   '78.72',
#   '-0.67%',
#   '446,012',
#   '206',
#   'ASHR',
#   'Xtrackers Harvest CSI 300 China A-Shares ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '30.17',
#   '-1.08%',
#   '11,627,651',
#   '207',
#   'ASHS',
#   'Xtrackers Harvest CSI 500 China-A Shares Small Cap ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '31.83',
#   '-0.96%',
#   '59,340',
#   '208',
#   'ASHX',
#   'Xtrackers MSCI China A Inclusion Equity ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '21.61',
#   '-0.83%',
#   '1,265',
#   '209',
#   'ASIX',
#   'AdvanSix Inc.',
#   'Basic Materials',
#   'Chemicals - Major Diversified',
#   'USA',
#   '863.88M',
#   '14.30',
#   '29.83',
#   '-0.83%',
#   '227,876',
#   '210',
#   'ASM',
#   'Avino Silver & Gold Mines Ltd.',
#   'Basic Materials',
#   'Silver',
#   'Canada',
#   '37.70M',
#   '21.85',
#   '0.59',
#   '2.88%',
#   '192,138',
#   '211',
#   'ASPN',
#   'Aspen Aerogels, Inc.',
#   'Industrial Goods',
#   'General Building Materials',
#   'USA',
#   '68.40M',
#   '-',
#   '2.87',
#   '-1.71%',
#   '16,100',
#   '212',
#   'ASR',
#   'Grupo Aeroportuario del Sureste, S. A. B. de C. V.',
#   'Services',
#   'Air Services, Other',
#   'Mexico',
#   '4.89B',
#   '19.18',
#   '166.52',
#   '1.65%',
#   '73,039',
#   '213',
#   'ASX',
#   'ASE Technology Holding Co., Ltd.',
#   'Technology',
#   'Semiconductor - Broad Line',
#   'Taiwan',
#   '9.75B',
#   '11.76',
#   '4.54',
#   '-0.22%',
#   '415,862',
#   '214',
#   'AT',
#   'Atlantic Power Corporation',
#   'Utilities',
#   'Electric Utilities',
#   'USA',
#   '272.00M',
#   '9.88',
#   '2.47',
#   '-1.59%',
#   '359,953',
#   '215',
#   'ATEN',
#   'A10 Networks, Inc.',
#   'Technology',
#   'Communication Equipment',
#   'USA',
#   '520.12M',
#   '-',
#   '6.90',
#   '-0.86%',
#   '219,949',
#   '216',
#   'ATGE',
#   'Adtalem Global Education Inc.',
#   'Services',
#   'Education & Training Services',
#   'USA',
#   '2.76B',
#   '20.85',
#   '47.66',
#   '-0.60%',
#   '243,540',
#   '217',
#   'ATH',
#   'Athene Holding Ltd.',
#   'Financial',
#   'Asset Management',
#   'Bermuda',
#   '7.81B',
#   '7.91',
#   '41.93',
#   '-2.89%',
#   '1,312,073',
#   '218',
#   'ATHM',
#   'Autohome Inc.',
#   'Technology',
#   'Internet Information Providers',
#   'China',
#   '12.70B',
#   '30.02',
#   '107.61',
#   '-2.15%',
#   '757,210',
#   '219',
#   'ATI',
#   'Allegheny Technologies Incorporated',
#   'Industrial Goods',
#   'Metal Fabrication',
#   'USA',
#   '3.36B',
#   '16.19',
#   '26.76',
#   '-0.78%',
#   '1,140,012',
#   '220',
#   'ATKR',
#   'Atkore International Group Inc.',
#   'Industrial Goods',
#   'Industrial Electrical Equipment',
#   'USA',
#   '1.06B',
#   '8.29',
#   '22.51',
#   '-2.30%',
#   '247,037'],
#  ['221',
#   'ATMP',
#   'Barclays ETN+ Select MLP ETN',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '20.43',
#   '-0.85%',
#   '39,718',
#   '222',
#   'ATNM',
#   'Actinium Pharmaceuticals, Inc.',
#   'Healthcare',
#   'Biotechnology',
#   'USA',
#   '70.42M',
#   '-',
#   '0.58',
#   '3.32%',
#   '663,411',
#   '223',
#   'ATO',
#   'Atmos Energy Corporation',
#   'Utilities',
#   'Gas Utilities',
#   'USA',
#   '11.65B',
#   '25.36',
#   '100.58',
#   '-0.34%',
#   '430,441',
#   '224',
#   'ATR',
#   'AptarGroup, Inc.',
#   'Consumer Goods',
#   'Packaging & Containers',
#   'USA',
#   '6.78B',
#   '37.05',
#   '108.16',
#   '-0.76%',
#   '183,397',
#   '225',
#   'ATTO',
#   'Atento S.A.',
#   'Services',
#   'Business Services',
#   'Luxembourg',
#   '296.24M',
#   '14.92',
#   '3.73',
#   '-0.80%',
#   '287,553',
#   '226',
#   'ATU',
#   'Actuant Corporation',
#   'Industrial Goods',
#   'Diversified Machinery',
#   'USA',
#   '1.55B',
#   '-',
#   '25.41',
#   '-1.28%',
#   '206,699',
#   '227',
#   'ATUS',
#   'Altice USA, Inc.',
#   'Technology',
#   'Telecom Services - Domestic',
#   'USA',
#   '15.30B',
#   '640.86',
#   '22.43',
#   '-0.80%',
#   '2,532,758',
#   '228',
#   'ATV',
#   'Acorn International, Inc.',
#   'Services',
#   'Catalog & Mail Order Houses',
#   'China',
#   '1.04B',
#   '3.33',
#   '30.52',
#   '2.58%',
#   '3,650',
#   '229',
#   'AU',
#   'AngloGold Ashanti Limited',
#   'Basic Materials',
#   'Gold',
#   'South Africa',
#   '5.60B',
#   '43.65',
#   '13.88',
#   '2.06%',
#   '2,544,683',
#   '230',
#   'AUG',
#   'Auryn Resources Inc.',
#   'Basic Materials',
#   'Industrial Metals & Minerals',
#   'Canada',
#   '152.67M',
#   '11.58',
#   '1.69',
#   '7.64%',
#   '349,100',
#   '231',
#   'AUGR',
#   'Defiance Future Tech ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '24.30',
#   '-0.16%',
#   '490',
#   '232',
#   'AUMN',
#   'Golden Minerals Company',
#   'Basic Materials',
#   'Industrial Metals & Minerals',
#   'USA',
#   '27.91M',
#   '-',
#   '0.30',
#   '0.47%',
#   '72,855',
#   '233',
#   'AUO',
#   'AU Optronics Corp.',
#   'Technology',
#   'Semiconductor - Broad Line',
#   'Taiwan',
#   '3.56B',
#   '11.04',
#   '3.73',
#   '0.54%',
#   '643,374',
#   '234',
#   'AUSF',
#   'Global X Adaptive U.S. Factor ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '24.37',
#   '-0.87%',
#   '44,812',
#   '235',
#   'AUY',
#   'Yamana Gold Inc.',
#   'Basic Materials',
#   'Gold',
#   'Canada',
#   '2.54B',
#   '-',
#   '2.67',
#   '1.91%',
#   '9,907,897',
#   '236',
#   'AVA',
#   'Avista Corporation',
#   'Utilities',
#   'Diversified Utilities',
#   'USA',
#   '2.67B',
#   '19.75',
#   '40.89',
#   '-0.20%',
#   '439,771',
#   '237',
#   'AVAL',
#   'Grupo Aval Acciones Y Valores S.A.',
#   'Financial',
#   'Foreign Regional Banks',
#   'Colombia',
#   '2.97B',
#   '11.12',
#   '8.45',
#   '3.55%',
#   '267,606',
#   '238',
#   'AVB',
#   'AvalonBay Communities, Inc.',
#   'Financial',
#   'REIT - Residential',
#   'USA',
#   '27.76B',
#   '28.56',
#   '200.60',
#   '-0.45%',
#   '464,247',
#   '239',
#   'AVD',
#   'American Vanguard Corporation',
#   'Basic Materials',
#   'Agricultural Chemicals',
#   'USA',
#   '513.31M',
#   '20.58',
#   '17.43',
#   '-1.69%',
#   '153,246',
#   '240',
#   'AVH',
#   'Avianca Holdings S.A.',
#   'Services',
#   'Regional Airlines',
#   'Panama',
#   '174.39M',
#   '-',
#   '4.29',
#   '-0.23%',
#   '68,382'],
#  ['241',
#   'AVK',
#   'Advent Claymore Convertible Securities and Income Fund',
#   'Financial',
#   'Closed-End Fund - Debt',
#   'USA',
#   '519.26M',
#   '-',
#   '15.04',
#   '-0.20%',
#   '94,291',
#   '242',
#   'AVLR',
#   'Avalara, Inc.',
#   'Technology',
#   'Application Software',
#   'USA',
#   '3.79B',
#   '-',
#   '55.47',
#   '-0.13%',
#   '367,756',
#   '243',
#   'AVNS',
#   'Avanos Medical, Inc.',
#   'Healthcare',
#   'Medical Instruments & Supplies',
#   'USA',
#   '2.10B',
#   '-',
#   '44.15',
#   '0.27%',
#   '244,040',
#   '244',
#   'AVP',
#   'Avon Products, Inc.',
#   'Consumer Goods',
#   'Personal Products',
#   'USA',
#   '1.25B',
#   '-',
#   '2.83',
#   '-1.74%',
#   '3,836,406',
#   '245',
#   'AVX',
#   'AVX Corporation',
#   'Technology',
#   'Diversified Electronics',
#   'USA',
#   '3.06B',
#   '13.22',
#   '18.26',
#   '-1.40%',
#   '374,698',
#   '246',
#   'AVY',
#   'Avery Dennison Corporation',
#   'Consumer Goods',
#   'Business Equipment',
#   'USA',
#   '9.42B',
#   '21.17',
#   '112.62',
#   '-1.13%',
#   '471,177',
#   '247',
#   'AVYA',
#   'Avaya Holdings Corp.',
#   'Services',
#   'Business Services',
#   'USA',
#   '2.04B',
#   '36.83',
#   '18.49',
#   '4.17%',
#   '5,806,234',
#   '248',
#   'AWF',
#   'AllianceBernstein Global High Income Fund',
#   'Financial',
#   'Closed-End Fund - Debt',
#   'USA',
#   '1.01B',
#   '265.23',
#   '11.67',
#   '0.00%',
#   '171,488',
#   '249',
#   'AWI',
#   'Armstrong World Industries, Inc.',
#   'Industrial Goods',
#   'General Building Materials',
#   'USA',
#   '4.16B',
#   '23.14',
#   '83.97',
#   '-0.44%',
#   '733,583',
#   '250',
#   'AWK',
#   'American Water Works Company, Inc.',
#   'Utilities',
#   'Water Utilities',
#   'USA',
#   '18.82B',
#   '32.49',
#   '104.57',
#   '0.41%',
#   '699,277',
#   '251',
#   'AWP',
#   'Aberdeen Global Premier Properties Fund',
#   'Financial',
#   'Closed-End Fund - Foreign',
#   'USA',
#   '510.74M',
#   '-',
#   '5.98',
#   '-0.83%',
#   '213,169',
#   '252',
#   'AWR',
#   'American States Water Company',
#   'Utilities',
#   'Water Utilities',
#   'USA',
#   '2.56B',
#   '40.45',
#   '69.58',
#   '-0.07%',
#   '106,298',
#   '253',
#   'AWX',
#   'Avalon Holdings Corporation',
#   'Industrial Goods',
#   'Waste Management',
#   'USA',
#   '9.52M',
#   '11.14',
#   '2.44',
#   '-2.98%',
#   '41,147',
#   '254',
#   'AX',
#   'Axos Financial, Inc.',
#   'Financial',
#   'Savings & Loans',
#   'USA',
#   '1.83B',
#   '11.71',
#   '30.55',
#   '-0.10%',
#   '357,361',
#   '255',
#   'AXE',
#   'Anixter International Inc.',
#   'Services',
#   'Industrial Equipment Wholesale',
#   'USA',
#   '1.94B',
#   '13.02',
#   '58.61',
#   '-2.82%',
#   '116,096',
#   '256',
#   'AXJL',
#   'WisdomTree Asia Pacific ex-Japan Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '68.57',
#   '-0.40%',
#   '588',
#   '257',
#   'AXJV',
#   'iShares Edge MSCI Min Vol Asia ex Japan ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '36.18',
#   '-0.05%',
#   '113',
#   '258',
#   'AXL',
#   'American Axle & Manufacturing Holdings, Inc.',
#   'Consumer Goods',
#   'Auto Parts',
#   'USA',
#   '1.74B',
#   '-',
#   '15.29',
#   '-2.55%',
#   '1,073,000',
#   '259',
#   'AXP',
#   'American Express Company',
#   'Financial',
#   'Credit Services',
#   'USA',
#   '91.44B',
#   '15.00',
#   '109.85',
#   '-0.77%',
#   '2,869,282',
#   '260',
#   'AXR',
#   'AMREP Corporation',
#   'Services',
#   'Business Services',
#   'USA',
#   '47.24M',
#   '28.59',
#   '5.89',
#   '1.90%',
#   '8,089'],
#  ['261',
#   'AXS',
#   'AXIS Capital Holdings Limited',
#   'Financial',
#   'Property & Casualty Insurance',
#   'Bermuda',
#   '4.61B',
#   '-',
#   '55.09',
#   '-1.31%',
#   '750,497',
#   '262',
#   'AXTA',
#   'Axalta Coating Systems Ltd.',
#   'Basic Materials',
#   'Specialty Chemicals',
#   'USA',
#   '6.33B',
#   '33.54',
#   '26.80',
#   '-1.11%',
#   '1,567,916',
#   '263',
#   'AXU',
#   'Alexco Resource Corp.',
#   'Basic Materials',
#   'Industrial Metals & Minerals',
#   'Canada',
#   '117.67M',
#   '-',
#   '1.10',
#   '0.00%',
#   '293,511',
#   '264',
#   'AYI',
#   'Acuity Brands, Inc.',
#   'Technology',
#   'Diversified Electronics',
#   'USA',
#   '5.51B',
#   '17.54',
#   '139.48',
#   '-0.21%',
#   '429,659',
#   '265',
#   'AYR',
#   'Aircastle Limited',
#   'Services',
#   'Rental & Leasing Services',
#   'USA',
#   '1.47B',
#   '6.10',
#   '19.45',
#   '-3.90%',
#   '312,095',
#   '266',
#   'AYX',
#   'Alteryx, Inc.',
#   'Technology',
#   'Application Software',
#   'USA',
#   '5.02B',
#   '248.18',
#   '80.66',
#   '-0.68%',
#   '704,526',
#   '267',
#   'AZN',
#   'AstraZeneca PLC',
#   'Healthcare',
#   'Drug Manufacturers - Major',
#   'United Kingdom',
#   '105.58B',
#   '47.87',
#   '40.69',
#   '-0.42%',
#   '4,313,064',
#   '268',
#   'AZO',
#   'AutoZone, Inc.',
#   'Services',
#   'Auto Parts Stores',
#   'USA',
#   '25.70B',
#   '19.83',
#   '1040.40',
#   '-1.15%',
#   '276,688',
#   '269',
#   'AZRE',
#   'Azure Power Global Limited',
#   'Utilities',
#   'Electric Utilities',
#   'India',
#   '479.60M',
#   '-',
#   '11.99',
#   '2.13%',
#   '16,226',
#   '270',
#   'AZUL',
#   'Azul S.A.',
#   'Services',
#   'Major Airlines',
#   'Brazil',
#   '3.14B',
#   '18.02',
#   '27.78',
#   '-1.35%',
#   '833,568',
#   '271',
#   'AZZ',
#   'AZZ Inc.',
#   'Industrial Goods',
#   'Diversified Machinery',
#   'USA',
#   '1.10B',
#   '26.08',
#   '42.61',
#   '-0.86%',
#   '90,574',
#   '272',
#   'B',
#   'Barnes Group Inc.',
#   'Industrial Goods',
#   'Industrial Equipment & Components',
#   'USA',
#   '2.70B',
#   '16.60',
#   '53.03',
#   '-1.60%',
#   '150,042',
#   '273',
#   'BA',
#   'The Boeing Company',
#   'Industrial Goods',
#   'Aerospace/Defense Products & Services',
#   'USA',
#   '210.40B',
#   '20.65',
#   '369.04',
#   '-1.46%',
#   '7,980,062',
#   '274',
#   'BAB',
#   'Invesco Taxable Municipal Bond ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '30.23',
#   '0.20%',
#   '90,127',
#   '275',
#   'BABA',
#   'Alibaba Group Holding Limited',
#   'Services',
#   'Specialty Retail, Other',
#   'China',
#   '474.03B',
#   '47.52',
#   '187.19',
#   '0.37%',
#   '11,578,209',
#   '276',
#   'BAC',
#   'Bank of America Corporation',
#   'Financial',
#   'Money Center Banks',
#   'USA',
#   '279.14B',
#   '11.07',
#   '28.89',
#   '-0.96%',
#   '40,535,280',
#   '277',
#   'BAF',
#   'BlackRock Municipal Income Investment Quality Trust',
#   'Financial',
#   'Closed-End Fund - Debt',
#   'USA',
#   '121.18M',
#   '-',
#   '13.85',
#   '0.36%',
#   '15,076',
#   '278',
#   'BAH',
#   'Booz Allen Hamilton Holding Corporation',
#   'Services',
#   'Management Services',
#   'USA',
#   '7.96B',
#   '19.15',
#   '57.38',
#   '-1.65%',
#   '906,823',
#   '279',
#   'BAK',
#   'Braskem S.A.',
#   'Basic Materials',
#   'Chemicals - Major Diversified',
#   'Brazil',
#   '10.00B',
#   '13.24',
#   '24.71',
#   '-1.67%',
#   '595,457',
#   '280',
#   'BAL',
#   'iPath Series B Bloomberg Cotton Subindex Total Return ETN',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '47.18',
#   '-0.79%',
#   '2,187'],
#  ['281',
#   'BAM',
#   'Brookfield Asset Management Inc.',
#   'Financial',
#   'Real Estate Development',
#   'Canada',
#   '46.97B',
#   '13.36',
#   '46.99',
#   '-0.57%',
#   '1,182,469',
#   '282',
#   'BANC',
#   'Banc of California, Inc.',
#   'Financial',
#   'Regional - Pacific Banks',
#   'USA',
#   '707.78M',
#   '37.21',
#   '14.29',
#   '-1.38%',
#   '247,802',
#   '283',
#   'BAP',
#   'Credicorp Ltd.',
#   'Financial',
#   'Money Center Banks',
#   'Peru',
#   '19.00B',
#   '15.83',
#   '240.05',
#   '-2.21%',
#   '221,728',
#   '284',
#   'BAR',
#   'GraniteShares Gold Trust',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '13.01',
#   '0.42%',
#   '46,264',
#   '285',
#   'BAS',
#   'Basic Energy Services, Inc.',
#   'Basic Materials',
#   'Oil & Gas Equipment & Services',
#   'USA',
#   '89.57M',
#   '-',
#   '3.56',
#   '-4.81%',
#   '387,015',
#   '286',
#   'BATT',
#   'Amplify Advanced Battery Metals and Materials ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '13.11',
#   '-0.83%',
#   '2,873',
#   '287',
#   'BAX',
#   'Baxter International Inc.',
#   'Healthcare',
#   'Medical Instruments & Supplies',
#   'USA',
#   '42.28B',
#   '30.73',
#   '80.07',
#   '0.51%',
#   '1,966,593',
#   '288',
#   'BB',
#   'BlackBerry Limited',
#   'Technology',
#   'Communication Equipment',
#   'Canada',
#   '5.10B',
#   '62.48',
#   '9.31',
#   '-0.53%',
#   '2,557,669',
#   '289',
#   'BBC',
#   'Virtus LifeSci Biotech Clinical Trials ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '29.01',
#   '-2.29%',
#   '8,957',
#   '290',
#   'BBD',
#   'Banco Bradesco S.A.',
#   'Financial',
#   'Foreign Regional Banks',
#   'Brazil',
#   '75.10B',
#   '13.36',
#   '9.35',
#   '-0.64%',
#   '9,405,914',
#   '291',
#   'BBDC',
#   'Barings BDC, Inc.',
#   'Financial',
#   'Credit Services',
#   'USA',
#   '501.88M',
#   '-',
#   '9.95',
#   '0.40%',
#   '171,705',
#   '292',
#   'BBDO',
#   'Banco Bradesco S.A.',
#   'Financial',
#   'Foreign Regional Banks',
#   'Brazil',
#   '64.82B',
#   '11.53',
#   '8.07',
#   '-1.59%',
#   '1,374',
#   '293',
#   'BBF',
#   'BlackRock Municipal Income Investment Trust',
#   'Financial',
#   'Closed-End Fund - Debt',
#   'USA',
#   '138.77M',
#   '67.51',
#   '13.57',
#   '0.67%',
#   '39,843',
#   '294',
#   'BBK',
#   'BlackRock Municipal Bond Trust',
#   'Financial',
#   'Closed-End Fund - Debt',
#   'USA',
#   '152.58M',
#   '62.50',
#   '14.50',
#   '0.76%',
#   '45,857',
#   '295',
#   'BBL',
#   'BHP Group',
#   'Basic Materials',
#   'Industrial Metals & Minerals',
#   'United Kingdom',
#   '135.94B',
#   '14.39',
#   '50.39',
#   '-0.96%',
#   '2,123,839',
#   '296',
#   'BBN',
#   'BlackRock Taxable Municipal Bond Trust',
#   'Financial',
#   'Closed-End Fund - Debt',
#   'USA',
#   '-',
#   '-',
#   '22.71',
#   '-0.04%',
#   '154,660',
#   '297',
#   'BBP',
#   'Virtus LifeSci Biotech Products ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '44.97',
#   '-1.85%',
#   '7,398',
#   '298',
#   'BBRC',
#   'Columbia Beyond BRICs ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '16.97',
#   '-0.18%',
#   '977',
#   '299',
#   'BBT',
#   'BB&T Corporation',
#   'Financial',
#   'Regional - Southeast Banks',
#   'USA',
#   '36.65B',
#   '12.36',
#   '47.90',
#   '-1.32%',
#   '4,418,780',
#   '300',
#   'BBU',
#   'Brookfield Business Partners L.P.',
#   'Financial',
#   'Real Estate Development',
#   'Bermuda',
#   '2.59B',
#   '68.12',
#   '39.10',
#   '0.77%',
#   '27,922'],
#  ['301',
#   'BBVA',
#   'Banco Bilbao Vizcaya Argentaria, S.A.',
#   'Financial',
#   'Foreign Regional Banks',
#   'Spain',
#   '40.00B',
#   '7.20',
#   '6.03',
#   '-0.33%',
#   '6,320,555',
#   '302',
#   'BBW',
#   'Build-A-Bear Workshop, Inc.',
#   'Services',
#   'Toy & Hobby Stores',
#   'USA',
#   '84.65M',
#   '-',
#   '5.83',
#   '-4.43%',
# ...
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '20.68',
#   '-1.78%',
#   '120,689'],
#  ['4101',
#   'WTM',
#   'White Mountains Insurance Group, Ltd.',
#   'Financial',
#   'Property & Casualty Insurance',
#   'Bermuda',
#   '2.90B',
#   '-',
#   '913.40',
#   '-0.86%',
#   '7,958',
#   '4102',
#   'WTMF',
#   'WisdomTree Managed Futures Strategy Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '39.03',
#   '0.05%',
#   '10,840',
#   '4103',
#   'WTR',
#   'Aqua America, Inc.',
#   'Utilities',
#   'Water Utilities',
#   'USA',
#   '6.50B',
#   '33.96',
#   '36.51',
#   '0.55%',
#   '354,510',
#   '4104',
#   'WTS',
#   'Watts Water Technologies, Inc.',
#   'Industrial Goods',
#   'Industrial Equipment & Components',
#   'USA',
#   '2.76B',
#   '22.66',
#   '81.93',
#   '-2.49%',
#   '208,681',
#   '4105',
#   'WTT',
#   'Wireless Telecom Group, Inc.',
#   'Technology',
#   'Communication Equipment',
#   'USA',
#   '32.99M',
#   '1510.00',
#   '1.51',
#   '0.67%',
#   '38,581',
#   '4106',
#   'WTTR',
#   'Select Energy Services, Inc.',
#   'Industrial Goods',
#   'Pollution & Treatment Controls',
#   'USA',
#   '1.21B',
#   '33.91',
#   '11.80',
#   '-3.67%',
#   '281,936',
#   '4107',
#   'WU',
#   'The Western Union Company',
#   'Financial',
#   'Credit Services',
#   'USA',
#   '8.58B',
#   '10.06',
#   '19.38',
#   '-0.51%',
#   '8,260,990',
#   '4108',
#   'WUBA',
#   '58.com Inc.',
#   'Technology',
#   'Internet Information Providers',
#   'China',
#   '10.66B',
#   '35.83',
#   '71.12',
#   '0.07%',
#   '449,135',
#   '4109',
#   'WWE',
#   'World Wrestling Entertainment, Inc.',
#   'Services',
#   'Entertainment - Diversified',
#   'USA',
#   '7.15B',
#   '81.50',
#   '91.04',
#   '1.12%',
#   '1,335,848',
#   '4110',
#   'WWW',
#   'Wolverine World Wide, Inc.',
#   'Consumer Goods',
#   'Textile - Apparel Footwear & Accessories',
#   'USA',
#   '3.19B',
#   '17.39',
#   '35.52',
#   '-1.96%',
#   '335,390',
#   '4111',
#   'WY',
#   'Weyerhaeuser Company',
#   'Industrial Goods',
#   'Lumber, Wood Production',
#   'USA',
#   '19.91B',
#   '27.06',
#   '26.60',
#   '-1.81%',
#   '3,086,550',
#   '4112',
#   'WYND',
#   'Wyndham Destinations, Inc.',
#   'Services',
#   'Lodging',
#   'USA',
#   '3.85B',
#   '15.27',
#   '41.29',
#   '-2.13%',
#   '549,775',
#   '4113',
#   'WYY',
#   'WidePoint Corporation',
#   'Technology',
#   'Information Technology Services',
#   'USA',
#   '39.75M',
#   '-',
#   '0.47',
#   '-0.11%',
#   '79,589',
#   '4114',
#   'X',
#   'United States Steel Corporation',
#   'Basic Materials',
#   'Steel & Iron',
#   'USA',
#   '3.10B',
#   '2.84',
#   '17.77',
#   '-9.98%',
#   '27,470,710',
#   '4115',
#   'XAN',
#   'Exantas Capital Corp.',
#   'Financial',
#   'REIT - Diversified',
#   'USA',
#   '337.92M',
#   '50.76',
#   '10.66',
#   '-0.93%',
#   '54,953',
#   '4116',
#   'XAR',
#   'SPDR S&P Aerospace & Defense ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '92.29',
#   '-1.56%',
#   '55,179',
#   '4117',
#   'XBI',
#   'SPDR S&P Biotech ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '91.45',
#   '-1.85%',
#   '3,883,436',
#   '4118',
#   'XCEM',
#   'Columbia EM Core ex-China ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '26.17',
#   '0.15%',
#   '1,919',
#   '4119',
#   'XDIV',
#   'Metaurus U.S. Equity Ex-Dividend Fund-Series 2027',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '58.08',
#   '0.98%',
#   '100',
#   '4120',
#   'XEC',
#   'Cimarex Energy Co.',
#   'Basic Materials',
#   'Independent Oil & Gas',
#   'USA',
#   '6.55B',
#   '8.03',
#   '66.82',
#   '-3.61%',
#   '1,096,173'],
#  ['4121',
#   'XES',
#   'SPDR S&P Oil & Gas Equipment & Services ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '11.98',
#   '-1.64%',
#   '1,185,662',
#   '4122',
#   'XFLT',
#   'XAI Octagon Floating Rate & Alternative Income Term Trust',
#   'Financial',
#   'Closed-End Fund - Debt',
#   'USA',
#   '-',
#   '-',
#   '8.73',
#   '-0.02%',
#   '3,548',
#   '4123',
#   'XHB',
#   'SPDR S&P Homebuilders ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '39.81',
#   '-1.44%',
#   '2,945,312',
#   '4124',
#   'XHE',
#   'SPDR S&P Health Care Equipment ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '79.18',
#   '-0.28%',
#   '45,854',
#   '4125',
#   'XHR',
#   'Xenia Hotels & Resorts, Inc.',
#   'Financial',
#   'REIT - Hotel/Motel',
#   'USA',
#   '2.43B',
#   '12.51',
#   '21.56',
#   '-2.88%',
#   '1,590,833',
#   '4126',
#   'XHS',
#   'SPDR S&P Health Care Services ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '65.41',
#   '-0.26%',
#   '26,179',
#   '4127',
#   'XIN',
#   'Xinyuan Real Estate Co., Ltd.',
#   'Financial',
#   'Real Estate Development',
#   'China',
#   '319.57M',
#   '11.19',
#   '4.98',
#   '0.40%',
#   '92,058',
#   '4128',
#   'XINA',
#   'SPDR MSCI China A Shares IMI ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '23.12',
#   '-0.64%',
#   '470',
#   '4129',
#   'XITK',
#   'SPDR FactSet Innovative Technology ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '105.95',
#   '-0.47%',
#   '4,817',
#   '4130',
#   'XKCP',
#   'SPDR Kensho Clean Power ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '34.51',
#   '-1.01%',
#   '162',
#   '4131',
#   'XKFF',
#   'SPDR Kensho Final Frontiers ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '30.64',
#   '-1.36%',
#   '424',
#   '4132',
#   'XKFS',
#   'SPDR Kensho Future Security ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '35.47',
#   '-0.79%',
#   '1,189',
#   '4133',
#   'XKII',
#   'SPDR Kensho Intelligent Structures ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '28.66',
#   '-1.39%',
#   '1,313',
#   '4134',
#   'XKST',
#   'SPDR Kensho Smart Mobility ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '28.72',
#   '-1.01%',
#   '651',
#   '4135',
#   'XLB',
#   'Materials Select Sector SPDR Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '57.42',
#   '-0.73%',
#   '6,110,767',
#   '4136',
#   'XLC',
#   'Communication Services Select Sector SPDR Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '48.36',
#   '0.27%',
#   '4,872,773',
#   '4137',
#   'XLE',
#   'Energy Select Sector SPDR Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '67.08',
#   '-1.22%',
#   '14,541,926',
#   '4138',
#   'XLF',
#   'Financial Select Sector SPDR Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '26.41',
#   '-0.83%',
#   '65,954,760',
#   '4139',
#   'XLG',
#   'Invesco S&P 500 Top 50 ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '206.61',
#   '-0.41%',
#   '19,679',
#   '4140',
#   'XLI',
#   'Industrial Select Sector SPDR Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '75.64',
#   '-1.36%',
#   '9,814,477'],
#  ['4141',
#   'XLK',
#   'Technology Select Sector SPDR Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '75.85',
#   '-0.47%',
#   '13,440,126',
#   '4142',
#   'XLP',
#   'Consumer Staples Select Sector SPDR Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '55.75',
#   '-0.13%',
#   '12,062,346',
#   '4143',
#   'XLRE',
#   'The Real Estate Select Sector SPDR Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '36.26',
#   '-0.30%',
#   '2,094,520',
#   '4144',
#   'XLU',
#   'Utilities Select Sector SPDR Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '57.83',
#   '0.24%',
#   '12,993,931',
#   '4145',
#   'XLV',
#   'Health Care Select Sector SPDR Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '91.74',
#   '-0.26%',
#   '7,207,595',
#   '4146',
#   'XLY',
#   'Consumer Discretionary Select Sector SPDR Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '116.88',
#   '-0.90%',
#   '4,456,471',
#   '4147',
#   'XME',
#   'SPDR S&P Metals and Mining ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '30.20',
#   '-2.52%',
#   '2,110,587',
#   '4148',
#   'XMLV',
#   'Invesco S&P MidCap Low Volatility ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '49.75',
#   '-0.86%',
#   '441,578',
#   '4149',
#   'XMX',
#   'WisdomTree Global ex-Mexico Equity Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '29.51',
#   '-0.59%',
#   '1,050',
#   '4150',
#   'XNTK',
#   'SPDR NYSE Technology ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '73.05',
#   '-0.42%',
#   '82,428',
#   '4151',
#   'XOM',
#   'Exxon Mobil Corporation',
#   'Basic Materials',
#   'Major Integrated Oil & Gas',
#   'USA',
#   '349.60B',
#   '16.80',
#   '81.93',
#   '-1.29%',
#   '8,561,582',
#   '4152',
#   'XOP',
#   'SPDR S&P Oil & Gas Exploration & Production ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '31.39',
#   '-2.00%',
#   '23,561,084',
#   '4153',
#   'XPH',
#   'SPDR S&P Pharmaceuticals ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '41.46',
#   '-1.89%',
#   '33,323',
#   '4154',
#   'XPL',
#   'Solitario Zinc Corp.',
#   'Basic Materials',
#   'Industrial Metals & Minerals',
#   'USA',
#   '24.78M',
#   '-',
#   '0.41',
#   '1.57%',
#   '67,452',
#   '4155',
#   'XPO',
#   'XPO Logistics, Inc.',
#   'Services',
#   'Air Delivery & Freight Services',
#   'USA',
#   '6.42B',
#   '20.68',
#   '59.76',
#   '-0.13%',
#   '1,702,862',
#   '4156',
#   'XPP',
#   'ProShares Ultra FTSE China 50',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '75.64',
#   '-0.40%',
#   '6,455',
#   '4157',
#   'XRF',
#   'China Rapid Finance Limited',
#   'Financial',
#   'Credit Services',
#   'China',
#   '71.89M',
#   '-',
#   '1.10',
#   '-0.90%',
#   '63,616',
#   '4158',
#   'XRLV',
#   'Invesco S&P 500 ex-Rate Sensitive Low Volatility ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '36.68',
#   '-0.68%',
#   '10,074',
#   '4159',
#   'XRT',
#   'SPDR S&P Retail ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '44.95',
#   '-1.21%',
#   '6,550,860',
#   '4160',
#   'XRX',
#   'Xerox Corporation',
#   'Technology',
#   'Information Technology Services',
#   'USA',
#   '7.56B',
#   '19.07',
#   '33.24',
#   '-1.51%',
#   '1,672,407'],
#  ['4161',
#   'XSD',
#   'SPDR S&P Semiconductor ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '82.79',
#   '-1.06%',
#   '63,844',
#   '4162',
#   'XSLV',
#   'Invesco S&P SmallCap Low Volatility ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '47.28',
#   '-1.07%',
#   '543,710',
#   '4163',
#   'XSOE',
#   'WisdomTree Emerging Markets ex-State-Owned Enterprises Fund',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '29.84',
#   '0.27%',
#   '62,656',
#   '4164',
#   'XSW',
#   'SPDR S&P Software & Services ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '94.55',
#   '-0.02%',
#   '26,572',
#   '4165',
#   'XTH',
#   'SPDR S&P Technology Hardware ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '76.52',
#   '-1.22%',
#   '82',
#   '4166',
#   'XTL',
#   'SPDR S&P Telecom ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '72.92',
#   '-0.57%',
#   '2,438',
#   '4167',
#   'XTN',
#   'SPDR S&P Transportation ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '61.99',
#   '-0.87%',
#   '5,139',
#   '4168',
#   'XTNT',
#   'Xtant Medical Holdings, Inc.',
#   'Healthcare',
#   'Medical Appliances & Equipment',
#   'USA',
#   '41.20M',
#   '-',
#   '3.13',
#   '1.55%',
#   '2,537',
#   '4169',
#   'XU',
#   'Elkhorn S&P MidCap Utilities',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '-',
#   '-',
#   '0',
#   '4170',
#   'XVZ',
#   'iPath S&P 500 Dynamic VIX ETN',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '18.06',
#   '0.11%',
#   '24',
#   '4171',
#   'XWEB',
#   'SPDR S&P Internet ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '90.03',
#   '-0.12%',
#   '5,887',
#   '4172',
#   'XXII',
#   '22nd Century Group, Inc.',
#   'Healthcare',
#   'Biotechnology',
#   'USA',
#   '219.56M',
#   '-',
#   '1.82',
#   '-3.19%',
#   '2,082,053',
#   '4173',
#   'XYF',
#   'X Financial',
#   'Financial',
#   'Credit Services',
#   'China',
#   '797.72M',
#   '6.27',
#   '5.45',
#   '0.09%',
#   '53,491',
#   '4174',
#   'XYL',
#   'Xylem Inc.',
#   'Industrial Goods',
#   'Diversified Machinery',
#   'USA',
#   '14.25B',
#   '25.88',
#   '79.57',
#   '-2.16%',
#   '730,195',
#   '4175',
#   'Y',
#   'Alleghany Corporation',
#   'Financial',
#   'Property & Casualty Insurance',
#   'USA',
#   '8.81B',
#   '452.20',
#   '609.11',
#   '-1.12%',
#   '68,648',
#   '4176',
#   'YANG',
#   'Direxion Daily FTSE China Bear 3X Shares',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '40.36',
#   '0.70%',
#   '383,549',
#   '4177',
#   'YCL',
#   'ProShares Ultra Yen',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '55.24',
#   '0.61%',
#   '933',
#   '4178',
#   'YCS',
#   'ProShares UltraShort Yen',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '76.96',
#   '-0.71%',
#   '1,611',
#   '4179',
#   'YELP',
#   'Yelp Inc.',
#   'Technology',
#   'Internet Information Providers',
#   'USA',
#   '2.89B',
#   '56.44',
#   '35.50',
#   '0.57%',
#   '828,153',
#   '4180',
#   'YETI',
#   'YETI Holdings, Inc.',
#   'Consumer Goods',
#   'Packaging & Containers',
#   'USA',
#   '2.51B',
#   '43.48',
#   '29.87',
#   '1.25%',
#   '1,028,627'],
#  ['4181',
#   'YEXT',
#   'Yext, Inc.',
#   'Technology',
#   'Internet Software & Services',
#   'USA',
#   '2.34B',
#   '-',
#   '21.50',
#   '-0.32%',
#   '501,094',
#   '4182',
#   'YINN',
#   'Direxion Daily FTSE China Bull 3X Shares',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '26.29',
#   '-0.83%',
#   '1,917,718',
#   '4183',
#   'YLD',
#   'Principal EDGE Active Income ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '39.92',
#   '-0.22%',
#   '1,506',
#   '4184',
#   'YMLI',
#   'VanEck Vectors High Income Infrastructure MLP ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '12.35',
#   '-0.88%',
#   '5,706',
#   '4185',
#   'YMLP',
#   'VanEck Vectors High Income MLP ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '20.18',
#   '-0.80%',
#   '3,786',
#   '4186',
#   'YPF',
#   'YPF Sociedad Anonima',
#   'Basic Materials',
#   'Major Integrated Oil & Gas',
#   'Argentina',
#   '5.77B',
#   '6.48',
#   '14.73',
#   '-2.26%',
#   '1,684,813',
#   '4187',
#   'YRD',
#   'Yirendai Ltd.',
#   'Financial',
#   'Credit Services',
#   'China',
#   '873.94M',
#   '6.39',
#   '14.79',
#   '-1.07%',
#   '227,995',
#   '4188',
#   'YUM',
#   'YUM! Brands, Inc.',
#   'Services',
#   'Restaurants',
#   'USA',
#   '30.63B',
#   '22.39',
#   '99.48',
#   '-0.11%',
#   '992,959',
#   '4189',
#   'YUMA',
#   'Yuma Energy, Inc.',
#   'Basic Materials',
#   'Independent Oil & Gas',
#   'USA',
#   '5.48M',
#   '-',
#   '0.23',
#   '38.24%',
#   '23,730,366',
#   '4190',
#   'YUMC',
#   'Yum China Holdings, Inc.',
#   'Services',
#   'Restaurants',
#   'China',
#   '16.50B',
#   '25.83',
#   '43.68',
#   '-1.06%',
#   '2,067,438',
#   '4191',
#   'YXI',
#   'ProShares Short FTSE China 50',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '17.92',
#   '0.39%',
#   '1,275',
#   '4192',
#   'YYY',
#   'YieldShares High Income ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '17.85',
#   '-0.34%',
#   '29,967',
#   '4193',
#   'ZAYO',
#   'Zayo Group Holdings, Inc.',
#   'Technology',
#   'Communication Equipment',
#   'USA',
#   '6.94B',
#   '67.39',
#   '29.45',
#   '-0.14%',
#   '2,798,530',
#   '4194',
#   'ZBH',
#   'Zimmer Biomet Holdings, Inc.',
#   'Healthcare',
#   'Medical Appliances & Equipment',
#   'USA',
#   '26.26B',
#   '-',
#   '128.66',
#   '-0.08%',
#   '1,183,786',
#   '4195',
#   'ZBK',
#   'Zions Bancorporation SUB NT FX/FLT 28',
#   'Financial',
#   'Regional - Pacific Banks',
#   'USA',
#   '-',
#   '-',
#   '29.05',
#   '-0.58%',
#   '6,640',
#   '4196',
#   'ZCAN',
#   'SPDR Solactive Canada ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '58.56',
#   '-0.54%',
#   '196',
#   '4197',
#   'ZDEU',
#   'SPDR Solactive Germany ETF',
#   'Financial',
#   'Exchange Traded Fund',
#   'USA',
#   '-',
#   '-',
#   '56.24',
#   '-0.88%',
#   '10',
#   '4198',
#   'ZDGE',
#   'Zedge, Inc.',
#   'Technology',
#   'Multimedia & Graphics Software',
#   'USA',
#   '19.71M',
#   '-',
#   '1.91',
#   '9.14%',
#   '4,106',
#   '4199',
#   'ZEN',
#   'Zendesk, Inc.',
#   'Technology',
#   'Application Software',
#   'USA',
#   '8.99B',
#   '-',
#   '82.60',
#   '0.99%',
#   '1,225,110',
#   '4200',
#   'ZF',
#   'Virtus Total Return Fund Inc.',
#   'Financial',
#   'Closed-End Fund - Equity',
#   'USA',
#   '220.23M',
#   '-',
#   '10.23',
#   '0.00%',
#   '261,139']]

# %%
flat_results = []
for sublist in results:
    for item in sublist:
        flat_results.append(item)

# %%
df = pd.DataFrame(flat_results)

# %%
data = pd.DataFrame(df.values.reshape(-1, 11), 
                    columns=['No','Ticker','Company','Sector','Industry',
                             'Country', 'Market Cap', 'P/E', 'Price','Change','Volume']).drop(['No'], axis=1)

# %%
data
# Out:
#      Ticker                                            Company  \
# 0         A                         Agilent Technologies, Inc.
# 1        AA                                  Alcoa Corporation
# 2      AAAU                       Perth Mint Physical Gold ETF
# 3       AAC                                 AAC Holdings, Inc.
# 4      AADR                AdvisorShares Dorsey Wright ADR ETF
# 5      AAMC            Altisource Asset Management Corporation
# 6       AAN                                      Aaron's, Inc.
# 7       AAP                           Advance Auto Parts, Inc.
# 8       AAT                        American Assets Trust, Inc.
# 9       AAU                              Almaden Minerals Ltd.
# 10       AB                     AllianceBernstein Holding L.P.
# 11      ABB                                            ABB Ltd
# 12     ABBV                                        AbbVie Inc.
# 13      ABC                      AmerisourceBergen Corporation
# 14     ABEV                                         Ambev S.A.
# 15      ABG                      Asbury Automotive Group, Inc.
# 16      ABM                        ABM Industries Incorporated
# 17      ABR                           Arbor Realty Trust, Inc.
# 18      ABT                                Abbott Laboratories
# 19       AC                     Associated Capital Group, Inc.
# 20      ACB                               Aurora Cannabis Inc.
# 21      ACC                  American Campus Communities, Inc.
# 22     ACCO                            ACCO Brands Corporation
# 23      ACH              Aluminum Corporation of China Limited
# 24     ACIM                             SPDR MSCI ACWI IMI ETF
# 25      ACM                                              AECOM
# 26      ACN                                      Accenture plc
# 27      ACP             Aberdeen Income Credit Strategies Fund
# 28     ACRE            Ares Commercial Real Estate Corporation
# 29     ACSG  Xtrackers MSCI ACWI ex USA ESG Leaders Equity ETF
# ...     ...                                                ...
# 4176    YCL                                ProShares Ultra Yen
# 4177    YCS                           ProShares UltraShort Yen
# 4178   YELP                                          Yelp Inc.
# 4179   YETI                                YETI Holdings, Inc.
# 4180   YEXT                                         Yext, Inc.
# 4181   YINN           Direxion Daily FTSE China Bull 3X Shares
# 4182    YLD                   Principal EDGE Active Income ETF
# 4183   YMLI  VanEck Vectors High Income Infrastructure MLP ETF
# 4184   YMLP                 VanEck Vectors High Income MLP ETF
# 4185    YPF                               YPF Sociedad Anonima
# 4186    YRD                                      Yirendai Ltd.
# 4187    YUM                                  YUM! Brands, Inc.
# 4188   YUMA                                  Yuma Energy, Inc.
# 4189   YUMC                           Yum China Holdings, Inc.
# 4190    YXI                      ProShares Short FTSE China 50
# 4191    YYY                        YieldShares High Income ETF
# 4192   ZAYO                          Zayo Group Holdings, Inc.
# 4193    ZBH                       Zimmer Biomet Holdings, Inc.
# 4194    ZBK              Zions Bancorporation SUB NT FX/FLT 28
# 4195   ZCAN                          SPDR Solactive Canada ETF
# 4196   ZDEU                         SPDR Solactive Germany ETF
# 4197   ZDGE                                        Zedge, Inc.
# 4198    ZEN                                      Zendesk, Inc.
# 4199     ZF                      Virtus Total Return Fund Inc.
# 4200    ZSL                        ProShares UltraShort Silver
# 4201    ZTO                          ZTO Express (Cayman) Inc.
# 4202    ZTR          Virtus Global Dividend & Income Fund Inc.
# 4203    ZTS                                        Zoetis Inc.
# 4204    ZUO                                        Zuora, Inc.
# 4205   ZYME                                     Zymeworks Inc.
#
#                 Sector                         Industry      Country  \
# 0           Healthcare  Medical Laboratories & Research          USA
# 1      Basic Materials                         Aluminum          USA
# 2            Financial             Exchange Traded Fund          USA
# 3           Healthcare      Specialized Health Services          USA
# 4            Financial             Exchange Traded Fund          USA
# 5            Financial                 Asset Management          USA
# 6             Services        Rental & Leasing Services          USA
# 7             Services                Auto Parts Stores          USA
# 8            Financial                    REIT - Retail          USA
# 9      Basic Materials                             Gold       Canada
# 10           Financial                 Asset Management          USA
# 11    Industrial Goods            Diversified Machinery  Switzerland
# 12          Healthcare       Drug Manufacturers - Major          USA
# 13            Services                  Drugs Wholesale          USA
# 14      Consumer Goods              Beverages - Brewers       Brazil
# 15            Services                 Auto Dealerships          USA
# 16            Services                Business Services          USA
# 17           Financial               REIT - Diversified          USA
# 18          Healthcare   Medical Appliances & Equipment          USA
# 19           Financial                 Asset Management          USA
# 20          Healthcare       Drug Manufacturers - Other       Canada
# 21           Financial               REIT - Residential          USA
# 22      Consumer Goods                  Office Supplies          USA
# 23     Basic Materials                         Aluminum        China
# 24           Financial             Exchange Traded Fund          USA
# 25            Services               Technical Services          USA
# 26          Technology  Information Technology Services      Ireland
# 27           Financial           Closed-End Fund - Debt          USA
# 28           Financial               REIT - Diversified          USA
# 29           Financial             Exchange Traded Fund          USA
# ...                ...                              ...          ...
# 4176         Financial             Exchange Traded Fund          USA
# 4177         Financial             Exchange Traded Fund          USA
# 4178        Technology   Internet Information Providers          USA
# 4179    Consumer Goods           Packaging & Containers          USA
# 4180        Technology     Internet Software & Services          USA
# 4181         Financial             Exchange Traded Fund          USA
# 4182         Financial             Exchange Traded Fund          USA
# 4183         Financial             Exchange Traded Fund          USA
# 4184         Financial             Exchange Traded Fund          USA
# 4185   Basic Materials       Major Integrated Oil & Gas    Argentina
# 4186         Financial                  Credit Services        China
# 4187          Services                      Restaurants          USA
# 4188   Basic Materials            Independent Oil & Gas          USA
# 4189          Services                      Restaurants        China
# 4190         Financial             Exchange Traded Fund          USA
# 4191         Financial             Exchange Traded Fund          USA
# 4192        Technology          Communication Equipment          USA
# 4193        Healthcare   Medical Appliances & Equipment          USA
# 4194         Financial         Regional - Pacific Banks          USA
# 4195         Financial             Exchange Traded Fund          USA
# 4196         Financial             Exchange Traded Fund          USA
# 4197        Technology   Multimedia & Graphics Software          USA
# 4198        Technology             Application Software          USA
# 4199         Financial         Closed-End Fund - Equity          USA
# 4200         Financial             Exchange Traded Fund          USA
# 4201          Services  Air Delivery & Freight Services        China
# 4202         Financial         Closed-End Fund - Equity          USA
# 4203        Healthcare                  Drugs - Generic          USA
# 4204        Technology             Application Software          USA
# 4205        Healthcare                    Biotechnology       Canada
#
#      Market Cap     P/E   Price  Change      Volume
# 0        25.89B   22.70   81.42  -0.33%   1,254,742
# 1         5.41B   24.21   29.10  -1.89%   2,355,477
# 2             -       -   13.02   0.50%      25,889
# 3        50.19M       -    2.10   1.94%      79,707
# 4             -       -   46.24  -0.68%       5,995
# 5        47.08M       -   29.80  -0.67%       3,288
# 6         3.59B   19.06   52.88  -1.27%     265,594
# 7        12.82B   31.06  175.65  -1.09%     616,239
# 8         2.14B  108.62   45.51  -1.07%     225,347
# 9        62.37M       -    0.57   1.20%      37,823
# 10        2.79B   11.59   29.02  -1.02%     227,646
# 11       42.46B   28.73   19.48  -1.37%   1,689,433
# 12      122.46B   22.82   82.69  -1.54%   3,712,813
# 13       16.07B   14.99   77.43  -0.88%     957,123
# 14       71.68B   25.91    4.56   1.56%  31,511,586
# 15        1.42B    8.65   71.74  -0.58%     104,915
# 16        2.40B   31.16   36.49  -1.54%     234,952
# 17        1.14B    9.13   13.49  -0.66%     900,900
# 18      137.52B   56.52   78.67   0.19%   4,836,715
# 19      890.48M       -   39.28   1.16%       3,151
# 20        8.50B   40.79    8.81  -2.54%  21,751,244
# 21        6.50B   56.54   47.44  -0.88%     609,182
# 22      865.88M    8.25    8.53  -2.18%     556,253
# 23       10.16B   84.02   10.67  -1.57%      75,469
# 24            -       -   79.77  -0.31%       2,679
# 25        4.77B   73.96   30.84  -1.91%     405,785
# 26      118.50B   25.63  177.73  -0.66%   1,813,989
# 27            -       -   12.33   0.08%      58,251
# 28      440.86M   11.45   15.42   0.00%     171,270
# 29            -       -   26.54  -0.29%         100
# ...         ...     ...     ...     ...         ...
# 4176          -       -   55.24   0.61%         933
# 4177          -       -   76.96  -0.71%       1,611
# 4178      2.89B   56.44   35.50   0.57%     828,153
# 4179      2.51B   43.48   29.87   1.25%   1,028,627
# 4180      2.34B       -   21.50  -0.32%     501,094
# 4181          -       -   26.29  -0.83%   1,917,718
# 4182          -       -   39.92  -0.22%       1,506
# 4183          -       -   12.35  -0.88%       5,706
# 4184          -       -   20.18  -0.80%       3,786
# 4185      5.77B    6.48   14.73  -2.26%   1,684,813
# 4186    873.94M    6.39   14.79  -1.07%     227,995
# 4187     30.63B   22.39   99.48  -0.11%     992,959
# 4188      5.48M       -    0.23  38.24%  23,730,366
# 4189     16.50B   25.83   43.68  -1.06%   2,067,438
# 4190          -       -   17.92   0.39%       1,275
# 4191          -       -   17.85  -0.34%      29,967
# 4192      6.94B   67.39   29.45  -0.14%   2,798,530
# 4193     26.26B       -  128.66  -0.08%   1,183,786
# 4194          -       -   29.05  -0.58%       6,640
# 4195          -       -   58.56  -0.54%         196
# 4196          -       -   56.24  -0.88%          10
# 4197     19.71M       -    1.91   9.14%       4,106
# 4198      8.99B       -   82.60   0.99%   1,225,110
# 4199    220.23M       -   10.23   0.00%     261,139
# 4200          -       -   38.76   0.42%      11,587
# 4201     14.56B   21.93   18.97   0.16%   1,277,304
# 4202    270.90M    5.03   11.06  -0.63%     145,666
# 4203     48.55B   35.73  101.46  -0.75%   1,657,141
# 4204      2.13B       -   19.68  -2.72%     720,290
# 4205    481.70M       -   15.66  -1.14%      36,380
#
# [4206 rows x 10 columns]
